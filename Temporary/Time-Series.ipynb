# %%
import pandas as pd
file = 'Bammel_Forest_Rain_Summary.csv'

# %%
data = pd.read_csv(file, encoding="ISO-8859-1",index_col=0)

# %%
data.head()
# Out:
#                Rain
# Date
# 1/1/2000 0:00  1.64
# 2/1/2000 0:00  1.00
# 3/1/2000 0:00  0.96
# 4/1/2000 0:00  3.64
# 5/1/2000 0:00  7.16

# %%
data.index = pd.to_datetime(data.index)
data.columns = ['Rainfall']
data.head()
# Out:
#             Rainfall
# Date
# 2000-01-01      1.64
# 2000-02-01      1.00
# 2000-03-01      0.96
# 2000-04-01      3.64
# 2000-05-01      7.16

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
data['Rainfall'].plot();
# plt.ylabel('Rainfall')

# %%
import plotly
plotly.tools.set_credentials_file(username='margsaniel', api_key='j8zJOwZ4eTolSYKYtlAP')
import cufflinks as cf

data.iplot(title="Bammel Forest Rainfall Jan 2000 to Jan 2018")
# Out:
# /Users/margretsaniel/anaconda3/lib/python3.6/site-packages/IPython/core/display.py:689: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~margsaniel/2.embed" height="525px" width="100%"></iframe>

# %%
from plotly.plotly import plot_mpl
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data, model='multiplicative')
fig = result.plot()
plot_mpl(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-940ba77d2e55> in <module>
#       1 from plotly.plotly import plot_mpl
#       2 from statsmodels.tsa.seasonal import seasonal_decompose
# ----> 3 result = seasonal_decompose(data, model='multiplicative')
#       4 fig = result.plot()
#       5 plot_mpl(fig)
#
# ~/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, freq, two_sided, extrapolate_trend)
#     117     if model.startswith('m'):
#     118         if np.any(x <= 0):
# --> 119             raise ValueError("Multiplicative seasonality is not appropriate "
#     120                              "for zero and negative values")
#     121
#
# ValueError: Multiplicative seasonality is not appropriate for zero and negative values

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-ccb552a10b7b> in <module>
# ----> 1 result = seasonal_decompose(data, data, model='multiplicative')
#       2 fig = result.plot()
#       3 plot_mpl(fig)
#
# TypeError: seasonal_decompose() got multiple values for argument 'model'
