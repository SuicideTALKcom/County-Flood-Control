# %%
#import dependencies and the web scraping code from scrape.py
from sqlalchemy import create_engine
import pymysql
import pandas as pd
import numpy as np 
import time
from datetime import datetime
import json

# from config import connection 

# def homes_comparison(scraped_homes):
    #create a connection to the sql database 
    

with open('scraped_homes.json', 'r') as output_file:
    output = str(output_file.read())
    new_data = json.loads(output)
    print(new_data)
    
# engine = create_engine("mysql://xq5039a54f2ukgye:pzghos28lbhgg711@otwsl2e23jrxcqvx.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/lmib79r99ct0zdgq", echo=False)
# conn = engine.connect()
# cur = conn.cursor()

try: 
    homesdf = pd.DataFrame(new_data)
#     print(homes)
except: 
    print("cant do it")
    #put the results of the function into a dataframe
#     homesdf = pd.DataFrame(scraped_homes)
    
homesdf['datetime'] = datetime.now()

print(homesdf)

homesdf.to_csv('data.csv', index = False)

#RUN THE QUERY AND GET THE ADDRESS FROM THE SQL DATABASE AS A LIST THEN GRAB THE ADDRESS FORM THE SCRAPED DATA AS A LIST THEN 
#FIND THE INDEX OF THE LIST OF ADDRESS FROM THE PANDAS DATAFRAME FOR WHICH THERE ARE NO MATCHES IN SQL 
#TO ILOC THE ROWS THAT ARE NOT IN SQL         
    
# for house in homesdf.iterrows():
    
#     retrieved_data = pd.read_sql("SELECT address FROM lmib79r99ct0zdgq.homes WHERE address = {}".format(house['address']), engine)
#     print(retrieved_data)
    

        

    #what happens when the same house is sold within 3 years? homes sold more than once. Compare datestamp and address if datestamp is one year old 
    #append the data anyways 

    #loop through the dataframe table and compare it to the web scrape info
    # for house in homesdf.iterrows():




    #loop thorugh each new df scrape and compare it against the sql database
    # for i, house in homesdf.iterrows():
        #read the sql database and take the address column to compare 
        # retrieved_data = pd.read_sql(f"SELECT address FROM lmib79r99ct0zdgq.homes WHERE address = '{house['address']}'", engine)
        #grab the address from the web scrape and  
        #compare if the address exists against the address column in the sql database
        # if retrieved_data.empty:
        #     homesdf.iloc[i].to_sql('lmib79r99ct0zdgq.homes', if_exists = 'append', schema= 'online', con=conn)

#     cur.execute(f"INSERT INTO lmib79r99ct0zdgq.homeVALUES homesdf")
    

#     conn.commit()
    
# cur.close()

# conn.close()
# Out:
# [{'neighborhood': 'sagemont', 'address': '10919 Sagecanyon Drive', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '1', 'agent': 'Nusrat Ghafoor', 'office': 'Walzel Properties', 'price': '224500'}, {'neighborhood': 'sagemont', 'address': '11010 Sagepark Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '8', 'agent': 'Amanda Escamilla', 'office': 'JLA Realty', 'price': '175000'}, {'neighborhood': 'sagemont', 'address': '11323 Sagevale Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '12', 'agent': 'Sonal Shah', 'office': 'REALM Real Estate Professionals - Sugar Land', 'price': '199990'}, {'neighborhood': 'sagemont', 'address': '11026 Sagemeadow Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '13', 'agent': 'Robert Roland', 'office': 'Realty Associates', 'price': '220000'}, {'neighborhood': 'sagemont', 'address': '11118 Sagedowne Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '5', 'agent': 'Sebastian Ponce', 'office': 'Ponce Realty & Investments', 'price': '199900'}, {'neighborhood': 'sagemont', 'address': '18922 Picnic Pavilion Court', 'city': 'Cypress', 'state': 'TX', 'zip': '77433', 'days': '21', 'agent': 'Richard Hale', 'office': 'Perry Development Management', 'price': '424900'}, {'neighborhood': 'sagemont', 'address': '10339 Sagerock Drive', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '21', 'agent': 'Rebecca Casey', 'office': 'Casey Castles, LLC', 'price': '148900'}, {'neighborhood': 'sagemont', 'address': '10818 Sageleaf Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '22', 'agent': 'Mark Benoit', 'office': 'RE/MAX 1st Source', 'price': '169900'}, {'neighborhood': 'sagemont', 'address': '10402 Sagedowne Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '5', 'agent': 'Davian Walker', 'office': "Houston's Choice Realty", 'price': '199000'}, {'neighborhood': 'sagemont', 'address': '10910 Sagetrail Drive', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '33', 'agent': 'Yesenia Guerra', 'office': 'CJM Realty Advisors', 'price': '204999'}, {'neighborhood': 'sagemont', 'address': '11602 Sagedowne Lane', 'city': 'Houston', 'state': 'TX', 'zip': '77089', 'days': '37', 'agent': 'Yaneth Zaragosa', 'office': 'Strada', 'price': '195000'}, {'neighborhood': 'riverwood estates', 'address': '6106 Great Oaks Drive', 'city': 'Houston', 'state': 'TX', 'zip': '77050', 'days': '15', 'agent': 'Marisa Lopez', 'office': 'Near Town Properties', 'price': '144700'}, {'neighborhood': 'forest shadows', 'address': '21807 Forest Glade Drive', 'city': 'Humble', 'state': 'TX', 'zip': '77338', 'days': '27', 'agent': 'Jodi Manfred', 'office': 'JLA Realty', 'price': '199000'}, {'neighborhood': 'forest shadows', 'address': '4706 Broadmark Lane', 'city': 'Humble', 'state': 'TX', 'zip': '77338', 'days': '66', 'agent': 'Cellina Stokes', 'office': 'Crowne Realty', 'price': '171500'}, {'neighborhood': 'forest shadows', 'address': '4602 Fieldwick Lane', 'city': 'Humble', 'state': 'TX', 'zip': '77338', 'days': '83', 'agent': 'Michael Thiltgen', 'office': 'Greenbriar Real Estate Service', 'price': '189900'}, {'neighborhood': 'forest shadows', 'address': '21802 Pine Cone Drive', 'city': 'Humble', 'state': 'TX', 'zip': '77338', 'days': '84', 'agent': 'Katherine Ware', 'office': 'Irie Properties, LLC', 'price': '239900'}, {'neighborhood': 'forest shadows', 'address': '4503 Clairfield Lane', 'city': 'Humble', 'state': 'TX', 'zip': '77338', 'days': '125', 'agent': 'Rick Raymor', 'office': 'RE/MAX Universal', 'price': '259500'}, {'neighborhood': 'aldine estates', 'address': '15202 Claypool Street', 'city': 'Houston', 'state': 'TX', 'zip': '77032', 'days': '114', 'agent': 'Rosa Gonzalez', 'office': 'REALM Real Estate Professionals - North Houston', 'price': '650000'}, {'neighborhood': 'castlewood', 'address': '2418 Toyah Avenue', 'city': 'Houston', 'state': 'TX', 'zip': '77039', 'days': '15', 'agent': 'Paula Plata', 'office': 'Keller Williams M ...
#                          address                   agent         city days  \
# 0         10919 Sagecanyon Drive          Nusrat Ghafoor      Houston    1
# 1            11010 Sagepark Lane        Amanda Escamilla      Houston    8
# 2            11323 Sagevale Lane              Sonal Shah      Houston   12
# 3          11026 Sagemeadow Lane           Robert Roland      Houston   13
# 4           11118 Sagedowne Lane         Sebastian Ponce      Houston    5
# 5    18922 Picnic Pavilion Court            Richard Hale      Cypress   21
# 6           10339 Sagerock Drive           Rebecca Casey      Houston   21
# 7            10818 Sageleaf Lane             Mark Benoit      Houston   22
# 8           10402 Sagedowne Lane           Davian Walker      Houston    5
# 9          10910 Sagetrail Drive          Yesenia Guerra      Houston   33
# 10          11602 Sagedowne Lane         Yaneth Zaragosa      Houston   37
# 11         6106 Great Oaks Drive            Marisa Lopez      Houston   15
# 12      21807 Forest Glade Drive            Jodi Manfred       Humble   27
# 16              forest shadows
# 17              aldine estates
# 18                  castlewood
# 19                  castlewood
# 20                  castlewood
# 21                  castlewood
# 22             lynwood estates
# 23      parkwood estates 77032
# 24           humble road place
# 25           humble road place
# 26    lake cypress estates u_r
# 27    lake cypress estates u_r
# 28    lake cypress estates u_r
# 29               bammel forest
# ..                         ...
# 113         home owned estates
# 114         home owned estates
# 115         home owned estates
# 116         home owned estates
# 117         home owned estates
# 118         home owned estates
# 119                 galenapark
# 120                 galenapark
# 121                 galenapark
# 122                 galenapark
# 123                 galenapark
# 124                 galenapark
# 125                 galenapark
# 126                 galenapark
# 127                 galenapark
# 128                 galenapark
# 129                 galenapark
# 130              braeburn glen
# 131              braeburn glen
# 132            highland shores
# 133            highland shores
# 134            highland shores
# 135            highland shores
# 136  san jacinto river estates
# 137              bliss meadows
# 138              bliss meadows
# 139              bliss meadows
# 140        crest haven estates
# 141             spenwick place
# 142             spenwick place
#
#                                                 office   price state    zip  \
# 0                                    Walzel Properties  224500    TX  77089
# 1                                           JLA Realty  175000    TX  77089
# 2         REALM Real Estate Professionals - Sugar Land  199990    TX  77089
# 3                                    Realty Associates  220000    TX  77089
# 4                           Ponce Realty & Investments  199900    TX  77089
# 5                         Perry Development Management  424900    TX  77433
# 6                                   Casey Castles, LLC  148900    TX  77089
# 7                                    RE/MAX 1st Source  169900    TX  77089
# 8                              Houston's Choice Realty  199000    TX  77089
# 9                                  CJM Realty Advisors  204999    TX  77089
# 10                                              Strada  195000    TX  77089
# 11                                Near Town Properties  144700    TX  77050
# 12                                          JLA Realty  199000    TX  77338
# 13                                       Crowne Realty  171500    TX  77338
# 14                      Greenbriar Real Estate Service  189900    TX  77338
# 15                                Irie Properties, LLC  239900    TX  77338
# 16                                    RE/MAX Universal  259500    TX  77338
# 17     REALM Real Estate Professionals - North Houston  650000    TX  77032
# 18                            Keller Williams Memorial  175000    TX  77039
# 19                                         Loft Realty  200000    TX  77039
# 20                       Century 21 Hardee-Team Realty  159000    TX  77039
# 21                                 Ability Real Estate  125000    TX  77039
# 22                                          JLA Realty  255000    TX  77373
# 23                           Nautilus Real Estate, Ltd  184900    TX  77032
# 24                            Mark Thomas & Associates   59900    TX  77396
# 25                            Mark Thomas & Associates   59900    TX  77396
# 26                                          Fast Homes  199000    TX  77429
# 27                                      eXp Realty LLC  100000    TX  77429
# 28   Better Homes and Gardens Real Estate Gary Gree...  384990    TX  77429
# 29                          RE/MAX Northwest, REALTORS  330000    TX  77068
# ..                                                 ...     ...   ...    ...
# 113                                 Prime Realty Group   89750    TX  77015
# 114                                    Turn Key Realty  149900    TX  77015
# 115                                  RE/MAX 1st Source   45500    TX  77015
# 116                                  Turner Mangum,LLC  160000    TX  77015
# 117                                  RE/MAX 1st Source   24500    TX  77015
# 118                          RE/MAX Real Estate Assoc.  265000    TX  77015
# 119                            Sierra Vista Realty LLC  119000    TX  77547
# 120                             Next Home First Source  144500    TX  77547
# 121                        RE/MAX Associates Northeast  300000    TX  77547
# 122  Better Homes and Gardens Real Estate Gary Gree...  145000    TX  77547
# 123                           Realty World Elite Group  189999    TX  77547
# 124                                   The Horizon Team  169999    TX  77547
# 125                                   The Horizon Team  129999    TX  77547
# 126                                     Houston Realty  120900    TX  77547
