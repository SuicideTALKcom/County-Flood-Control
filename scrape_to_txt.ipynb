# %%
import os
import time
import csv
import requests
from bs4 import BeautifulSoup
from pprint import pprint
from urllib import parse
import re 
from datetime import datetime
import schedule
import threading
import itertools
import ast
# from task import homes_comparison

urls = [
        "https://www.har.com/forest-shadows/homes-for-sale/4585?sort=listdate+desc",
           "https://www.har.com/aldine-estates/homes-for-sale/1917?sort=listdate+desc"]
#            "https://www.har.com/greenbranch/homes-for-sale/1921?sort=listdate+desc",
#            "https://www.har.com/castlewood/homes-for-sale/2078?sort=listdate+desc",
#            "https://www.har.com/bamwood-terrace/homes-for-sale/3693?sort=listdate+desc",
#            "https://www.har.com/lynwood-estates/homes-for-sale/5152?sort=listdate+desc",
#            "https://www.har.com/parkwood-estates-77032/homes-for-sale/1911?sort=listdate+desc",
#             "https://www.har.com/humble-road-place/homes-for-sale/5738?sort=listdate+desc",
#             "https://www.har.com/langley-road-place/homes-for-sale/3838?sort=listdate+desc",
#             "https://www.har.com/sandbar-estates/homes-for-sale/9033?sort=listdate+desc",
#             "https://www.har.com/houston-hot-wells/homes-for-sale/6115?sort=listdate+desc",
#             "https://www.har.com/lake-cypress-estates-u_r/homes-for-sale/6010?sort=listdate+desc",
#             "https://www.har.com/bammel-forest/homes-for-sale/2893?sort=listdate+desc",
#             "https://www.har.com/airline-farms/homes-for-sale/2045?sort=listdate+desc",
#             "https://www.har.com/norchester/homes-for-sale/2949?sort=listdate+desc",
#             "https://www.har.com/grantwood/homes-for-sale/6022?sort=listdate+desc"]
# "https://www.har.com/riverwood-estates/homes-for-sale/2377?sort=listdate+desc",

all_homes = []

for url in urls:
    html = requests.get(url, timeout= 5).text
    soup = BeautifulSoup(html, 'lxml')
    price, homes = itertools.tee(soup.find_all("div", class_="prop_list"))
    neighborhood = url.split('/')[3].replace('-',' ')
    if soup.find_all("h2", {"class":"charcole reguler"}):
        pass

    for item in homes: 
        try:
            for info in item.find_all(class_= 'mpi_info'):
                try:
                    full_address = info.find_all('a', class_= 'address')[0].text
                    split_address = full_address.split(',')
                    use_split_address = split_address[0].strip()
                    use_split_city = split_address[1].strip()
                    state_zip = split_address[2].split(' ')
                    use_state = state_zip[1].strip()
                    use_zip = state_zip[2].strip()
                    use_days = info.find_all('span', class_= 'bold')[1].text
                    use_agent = info.find_all('a', class_='bold')[0].text 
                    use_office = info.find_all('a', class_= 'bold')[1].text.strip()

                    home_info=  {
                        "neighborhood": neighborhood,
                        "address": use_split_address,
                        "city": use_split_city,
                        "state": use_state,
                        "zip": use_zip,
                        "days": use_days,
                        "agent": use_agent,
                        "office": use_office}
                    all_homes.append(home_info)
                except:
#                     print("no info")
                    continue 

        except:
#             print("No results given for " + url)
            continue
            




#         for p in price:
#             try:
#                 for price_div in p.find_all(class_='price'):

#                     try:
#                         price_div.find('img').decompose()
#                     except:
#                         print()

#                     price_list = price_div.text.replace('$', '').replace(',','').strip('][')


#                     new_price = price_list[2:8].strip().split('/n')

#                     for new in new_price:
#                         final_price = {
#                             "price": new
#                             }

#                     all_homes.append(final_price)

#             except:
#                 print("exception occured")
#                 continue


            





# half_len_cities = round(len(all_homes)/2)
# for index in range(half_len_cities):
#     print(index)
#     try:
#         all_homes[index]["price"] = all_homes[half_len_cities]["price"]
#         del all_homes[half_len_cities]
#     except KeyError:
#         raise ValueError('No "price" key in "%s"' % (index, ))



print(all_homes)
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-f2c4f719ad68> in <module>
#     117     try:
# --> 118         all_homes[index]["price"] = all_homes[half_len_cities]["price"]
#     119         del all_homes[half_len_cities]
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-f2c4f719ad68> in <module>
#     119         del all_homes[half_len_cities]
#     120     except KeyError:
# --> 121         raise ValueError('No "price" key in "%s"' % (index, ))
#     122
#     123
#
# ValueError: No "price" key in "4"

# %%
import os
import time
import csv
import requests
from bs4 import BeautifulSoup
from pprint import pprint
from urllib import parse
import re 
from datetime import datetime
import schedule
import threading
import itertools
import ast
# from task import homes_comparison
import json

def har_homes():
    urls = ["https://www.har.com/riverwood-estates/homes-for-sale/2377?sort=listdate+desc",
            "https://www.har.com/forest-shadows/homes-for-sale/4585?sort=listdate+desc",
           "https://www.har.com/aldine-estates/homes-for-sale/1917?sort=listdate+desc"
           "https://www.har.com/greenbranch/homes-for-sale/1921?sort=listdate+desc",
           "https://www.har.com/castlewood/homes-for-sale/2078?sort=listdate+desc",
           "https://www.har.com/bamwood-terrace/homes-for-sale/3693?sort=listdate+desc",
           "https://www.har.com/lynwood-estates/homes-for-sale/5152?sort=listdate+desc",
           "https://www.har.com/parkwood-estates-77032/homes-for-sale/1911?sort=listdate+desc",
            "https://www.har.com/humble-road-place/homes-for-sale/5738?sort=listdate+desc",
            "https://www.har.com/langley-road-place/homes-for-sale/3838?sort=listdate+desc",
            "https://www.har.com/sandbar-estates/homes-for-sale/9033?sort=listdate+desc",
            "https://www.har.com/houston-hot-wells/homes-for-sale/6115?sort=listdate+desc",
            "https://www.har.com/lake-cypress-estates-u_r/homes-for-sale/6010?sort=listdate+desc",
            "https://www.har.com/bammel-forest/homes-for-sale/2893?sort=listdate+desc",
            "https://www.har.com/airline-farms/homes-for-sale/2045?sort=listdate+desc",
            "https://www.har.com/norchester/homes-for-sale/2949?sort=listdate+desc",
            "https://www.har.com/grantwood/homes-for-sale/6022?sort=listdate+desc",
            "https://www.har.com/windwood-extn-u_r/homes-for-sale/6015?sort=listdate+desc",
            "https://www.har.com/coles-crossing/homes-for-sale/6066?sort=listdate+desc",
            "https://www.har.com/woodwind-lakes/homes-for-sale/2113?sort=listdate+desc",
            "https://www.har.com/woodland-trails-west/homes-for-sale/2103?sort=listdate+desc",
            "https://www.har.com/inwood-pines/homes-for-sale/3649?sort=listdate+desc",
            "https://www.har.com/independence-heights/homes-for-sale/1049?sort=listdate+desc",
            "https://www.har.com/langwood/homes-for-sale/3775?sort=listdate+desc",
            "https://www.har.com/kempwood/homes-for-sale/3355?sort=listdate+desc",
            "https://www.har.com/home-owned-estates/homes-for-sale/947?sort=listdate+desc",
            "https://www.har.com/galenapark/realestate/for_sale?sort=listdate+desc",
            "https://www.har.com/braeburn-glen/homes-for-sale/3076?sort=listdate+desc",
            "https://www.har.com/highland-shores/homes-for-sale/9027?sort=listdate+desc",
            "https://www.har.com/san-jacinto-river-estates/homes-for-sale/8074?sort=listdate+desc",
            "https://www.har.com/bliss-meadows/homes-for-sale/7292?sort=listdate+desc",
            "https://www.har.com/bramley/homes-for-sale/7249?sort=listdate+desc",
            "https://www.har.com/crest-haven-estates/homes-for-sale/7290?sort=listdate+desc",
            "https://www.har.com/spenwick-place/homes-for-sale/9397?sort=listdate+desc",
            "https://www.har.com/sagemont/homes-for-sale/3666?sort=listdate+desc"]

    all_homes = []

    for url in urls:
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'lxml')
        price, homes = itertools.tee(soup.find_all("div", class_="prop_list"))
        neighborhood = url.split('/')[3].replace('-',' ')
        if soup.find_all("h2", {"class":"charcole reguler"}):
            pass

        for item in homes: 
            try:
                for info in item.find_all(class_= 'mpi_info'):
                    full_address = info.find_all('a', class_= 'address')[0].text
                    split_address = full_address.split(',')
                    use_split_address = split_address[0].strip()
                    use_split_city = split_address[1].strip()
                    state_zip = split_address[2].split(' ')
                    use_state = state_zip[1].strip()
                    use_zip = state_zip[2].strip()
                    use_days = info.find_all('span', class_= 'bold')[1].text
                    use_agent = info.find_all('a', class_='bold')[0].text 
                    use_office = info.find_all('a', class_= 'bold')[1].text.strip()

                    home_info=  {
                        "neighborhood": neighborhood,
                        "address": use_split_address,
                        "city": use_split_city,
                        "state": use_state,
                        "zip": use_zip,
                        "days": use_days,
                        "agent": use_agent,
                        "office": use_office}
                    all_homes.append(home_info)


            except:
                print("No results given for " + url)
                continue



#         for p in price:
#             try:
#                 for price_div in p.find_all(class_='price'):

#                     try:
#                         price_div.find('img').decompose()
#                     except:
#                         print()

#                     price_list = price_div.text.replace('$', '').replace(',','').strip('][')


#                     new_price = price_list[2:8].strip().split('/n')

#                     for new in new_price:
#                         final_price = {
#                             "price": new
#                             }

#                     all_homes.append(final_price)

#             except:
#                 print("exception occured")
#                 continue





#     half_len_cities = round(len(all_homes)/2)
#     for index in range(half_len_cities):
#         all_homes[index]["price"] = all_homes[half_len_cities]["price"]
#         del all_homes[half_len_cities]


#     print(all_homes)
    return all_homes



# with open('scraped_homes.txt', 'w') as output_file:
#     json.dump(all_homes, output_file)
    

har_homes()

# def compare():
#     homes_comparison(scraped_homes = har_homes())
#     # print("banana")

# def threader(job_func):
#     job_thread = threading.Thread(target=job_func)
#     job_thread.start()

#     schedule.every(180).seconds.do(threader, compare)

# def main():    
#     schedule.run_pending()
#     time.sleep(1)
# Out:
# [{'neighborhood': 'riverwood estates',
#   'address': '6106 Great Oaks Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77050',
#   'days': '15',
#   'agent': 'Marisa Lopez',
#   'office': 'Near Town Properties'},
#  {'price': '144700'},
#  {'neighborhood': 'forest shadows',
#   'address': '21807 Forest Glade Drive',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '24',
#   'agent': 'Jodi Manfred',
#   'office': 'JLA Realty'},
#  {'neighborhood': 'forest shadows',
#   'address': '4706 Broadmark Lane',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '66',
#   'agent': 'Cellina Stokes',
#   'office': 'Crowne Realty'},
#  {'neighborhood': 'forest shadows',
#   'address': '4602 Fieldwick Lane',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '80',
#   'agent': 'Michael Thiltgen',
#   'office': 'Greenbriar Real Estate Service'},
#  {'neighborhood': 'forest shadows',
#   'address': '21802 Pine Cone Drive',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '81',
#   'agent': 'Katherine Ware',
#   'office': 'Irie Properties, LLC'},
#  {'neighborhood': 'forest shadows',
#   'address': '4503 Clairfield Lane',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '122',
#   'agent': 'Rick Raymor',
#   'office': 'RE/MAX Universal'},
#  {'price': '199000'},
#  {'price': '171500'},
#  {'price': '189900'},
#  {'price': '239900'},
#  {'price': '259500'},
#  {'neighborhood': 'aldine estates',
#   'address': '15202 Claypool Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77032',
#   'days': '111',
#   'agent': 'Rosa Gonzalez',
#   'office': 'REALM Real Estate Professionals - North Houston'},
#  {'price': '650000'},
#  {'neighborhood': 'castlewood',
#   'address': '2418 Toyah Avenue',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '15',
#   'agent': 'Paula Plata',
#   'office': 'Keller Williams Memorial'},
#  {'neighborhood': 'castlewood',
#   'address': '2517 Woodgate Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '109',
#   'agent': 'Gina Lopez',
#   'office': 'Loft Realty'},
#  {'neighborhood': 'castlewood',
#   'address': '2802 Rosebury Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '131',
#   'agent': 'Esmeralda Herrera',
#   'office': 'Century 21 Hardee-Team Realty'},
#  {'neighborhood': 'castlewood',
#   'address': '2615 Balmorhea Avenue',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '169',
#   'agent': 'Mary Villarreal',
#   'office': 'Ability Real Estate'},
#  {'price': '175000'},
#  {'price': '200000'},
#  {'price': '159000'},
#  {'price': '125000'},
#  {'neighborhood': 'lynwood estates',
#   'address': '906 Lynwood Road',
#   'city': 'Spring',
#   'state': 'TX',
#   'zip': '77373',
#   'days': '17',
#   'agent': 'Rania Hanania',
#   'office': 'JLA Realty'},
#  {'neighborhood': 'lynwood estates',
#   'address': '1311 Lynwood Road',
#   'city': 'Spring',
#   'state': 'TX',
#   'zip': '77373',
#   'days': '4',
#   'agent': 'Gidget Sauceda',
#   'office': 'RE/MAX Universal'},
#  {'price': '255000'},
#  {'price': '189900'},
#  {'neighborhood': 'parkwood estates 77032',
#   'address': '14301 Lee Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77032',
#   'days': '164',
#   'agent': 'Maria Salazar',
#   'office': 'Nautilus Real Estate, Ltd'},
#  {'price': '184900'},
#  {'neighborhood': 'lake cypress estates u_r',
#   'address': '13200 Huffmeister Road',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '20',
#   'agent': 'Amjad Mushtaq',
#   'office': 'Fast Homes'},
#  {'neighborhood': 'lake cypress estates u_r',
#   'address': '0 Maxwell Road',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '84',
#   'agent': 'Kristi Grimes',
#   'office': 'eXp Realty LLC'},
#  {'neighborhood': 'lake cypress estates u_r',
#   'address': '13026 Maxwell Road',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '244',
#   'agent': 'Ryan Jockers',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions'},
#  {'price': '199000'},
#  {'price': '100000'},
#  {'price': '384990'},
#  {'neighborhood': 'bammel forest',
#   'address': '16314 Waycreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '3',
#   'agent': 'Arlene Simmons',
#   'office': 'RE/MAX Integrity'},
#  {'neighborhood': 'bammel forest',
#   'address': '2511 Bycreek Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '8',
#   'agent': 'Lisa Shackleton',
#   'office': 'JLA Realty'},
#  {'neighborhood': 'bammel forest',
#   'address': '2618 Colwell Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '23',
#   'agent': 'Gay Perque',
#   'office': 'RE/MAX Vintage'},
#  {'neighborhood': 'bammel forest',
#   'address': '16211 Creeksouth Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '25',
#   'agent': 'Cameron Namazi',
#   'office': 'Summit Realty'},
#  {'neighborhood': 'bammel forest',
#   'address': '16523 Waycreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '28',
#   'agent': 'Yvonne Chauvin',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene'},
#  {'neighborhood': 'bammel forest',
#   'address': '2610 Creekhickory Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '60',
#   'agent': 'Rick Shelton',
#   'office': 'The Horizon Team'},
#  {'neighborhood': 'bammel forest',
#   'address': '2402 Encreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '65',
#   'agent': 'Rick Shelton',
#   'office': 'The Horizon Team'},
#  {'neighborhood': 'bammel forest',
#   'address': '2503 Encreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '43',
#   'agent': 'Angela Muniz',
#   'office': 'Champions Real Estate Group'},
#  {'neighborhood': 'bammel forest',
#   'address': '2319 Encreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '235',
#   'agent': 'Rick Shelton',
#   'office': 'The Horizon Team'},
#  {'neighborhood': 'bammel forest',
#   'address': '16911 Creeksouth Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '119',
#   'agent': 'Cecilia Hernandez',
#   'office': 'Champions Real Estate Group'},
#  {'price': '219000'},
#  {'price': '210000'},
#  {'price': '189500'},
#  {'price': '214900'},
#  {'price': '230000'},
#  {'price': '241990'},
#  {'price': '272500'},
#  {'price': '249900'},
#  {'price': '244990'},
#  {'price': '289900'},
#  {'neighborhood': 'airline farms',
#   'address': '9501 North Freeway',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77037',
#   'days': '689',
#   'agent': 'Benito Armas',
#   'office': 'Armas Realty'},
#  {'price': '750000'},
#  {'neighborhood': 'norchester',
#   'address': '10530 Normont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '18',
#   'agent': 'Alfonso Parodi',
#   'office': 'Realty Associates'},
#  {'neighborhood': 'norchester',
#   'address': '10522 Idlebrook Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '24',
#   'agent': 'Jose Portillo',
#   'office': 'Champions Real Estate Group'},
#  {'neighborhood': 'norchester',
#   'address': '10722 Fawnview Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '23',
#   'agent': 'Dee Pardue',
#   'office': 'NextHome Realty Center'},
#  {'neighborhood': 'norchester',
#   'address': '10906 Archmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '37',
#   'agent': 'J.P. Bowers',
#   'office': 'RE/MAX Westside, REALTORS'},
#  {'neighborhood': 'norchester',
#   'address': '10723 Brentway Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '5',
#   'agent': 'Timothy Merritt',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions'},
#  {'neighborhood': 'norchester',
#   'address': '10530 Glenway Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '15',
#   'agent': 'Angelica Fernandez',
#   'office': 'RE/MAX Signature'},
#  {'neighborhood': 'norchester',
#   'address': '10515 Laneview Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '52',
#   'agent': 'Rebecca Robertson',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene'},
#  {'neighborhood': 'norchester',
#   'address': '10818 Elmdale Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '60',
#   'agent': 'Albert Tapia',
#   'office': 'Champions Real Estate Group'},
#  {'neighborhood': 'norchester',
#   'address': '10511 Moorcreek',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '77',
#   'agent': 'Lisa Pittman',
#   'office': 'NextHome Realty Center'},
#  {'neighborhood': 'norchester',
#   'address': '10610 Normont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '77',
#   'agent': 'Karen Davis',
#   'office': 'Karen Davis Properties'},
#  {'neighborhood': 'norchester',
#   'address': '10803 Fawnview Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '100',
#   'agent': 'Lex Parker',
#   'office': 'MHW Real Estate, Inc.'},
#  {'neighborhood': 'norchester',
#   'address': '10534 Jaycreek Drive',
#   'city': 'North Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '113',
#   'agent': 'Chuck Pounds',
#   'office': 'REALM Real Estate Professionals - North Houston'},
#  {'price': '290000'},
#  {'price': '279700'},
#  {'price': '224500'},
#  {'price': '275000'},
#  {'price': '236000'},
#  {'price': '279999'},
#  {'price': '247000'},
#  {'price': '254800'},
#  {'price': '255000'},
#  {'price': '34900'},
#  {'price': '185000'},
#  {'price': '299500'},
#  {'neighborhood': 'windwood extn u_r',
#   'address': '11934 Deep Woods Drive Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '143',
#   'agent': 'Miriam Ackley',
#   'office': 'On the Market Realty, Inc'},
#  {'price': '399999'},
#  {'neighborhood': 'coles crossing',
#   'address': '13927 Sherburn Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '9',
#   'agent': 'Raymond LaFuente',
#   'office': 'RE/MAX Integrity'},
#  {'neighborhood': 'coles crossing',
#   'address': '15839 Cypress Hall Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '10',
#   'agent': 'David Flory',
#   'office': 'RE/MAX Universal'},
#  {'neighborhood': 'coles crossing',
#   'address': '14231 Northface Manor Court',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '4',
#   'agent': 'Terri Garza',
#   'office': 'NextHome Realty Center'},
#  {'neighborhood': 'coles crossing',
#   'address': '13823 Sherburn Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '5',
#   'agent': 'Tracy Hughes',
#   'office': 'Coldwell Banker United, Realtors - CY Fair'},
#  {'neighborhood': 'coles crossing',
#   'address': '13714 Sherburn Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '12',
#   'agent': 'Astrid West',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene'},
#  {'neighborhood': 'coles crossing',
#   'address': '13526 Greenwood Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '2',
#   'agent': 'Amy Lippincott',
#   'office': 'Keller Williams Platinum'},
#  {'neighborhood': 'coles crossing',
#   'address': '16306 Wytchwood Circle',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '13',
#   'agent': 'Jeanne Skinner',
#   'office': 'Walzel Properties - Corporate Office'},
#  {'neighborhood': 'coles crossing',
#   'address': '16314 Madewood Street',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '71463878',
#   'agent': 'Jill Smith',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene'},
#  {'neighborhood': 'coles crossing',
#   'address': '14035 Fosters Creek Drive Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '36',
#   'agent': 'Tanya Bailey',
#   'office': 'Texas United Realty'},
#  {'neighborhood': 'coles crossing',
#   'address': '13927 Prospect Point Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '15',
#   'agent': 'Tanya Langner',
#   'office': 'Levine & Co. Real Estate LLC'},
#  {'neighborhood': 'coles crossing',
#   'address': '13415 N Bend Landing',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '18',
#   'agent': 'Rochelle Barrow',
#   'office': 'Berkshire Hathaway HomeServices Anderson Properties'},
#  {'neighborhood': 'coles crossing',
#   'address': '14646 Bergenia Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '2',
#   'agent': 'Melanie Dubendorff',
#   'office': 'Keller Williams Platinum'},
#  {'price': '299999'},
#  {'price': '300000'},
#  {'price': '499000'},
#  {'price': '305000'},
#  {'price': '269900'},
#  {'price': '475000'},
#  {'price': '278000'},
#  {'price': '315000'},
#  {'price': '337000'},
#  {'price': '315000'},
#  {'price': '519000'},
#  {'price': '234913'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '8114 Clarion Way',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '1',
#   'agent': 'Colleen Sherlock',
#   'office': 'Greenwood King Properties'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '7907 Ensemble Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '16',
#   'agent': 'Lance Loken',
#   'office': 'Keller Williams Platinum'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '8018 Sonata Court',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '6',
#   'agent': 'Lynn Collins',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9346 Adagio Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '24',
#   'agent': 'Lynn Collins',
#   'office': 'BHGRE Gary Greene'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9223 Symphonic Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '35',
#   'agent': 'Sonia Cousins',
#   'office': 'RE/MAX Fine Properties'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9106 Symphonic Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '27',
#   'agent': 'Paula Forno-Engler',
#   'office': 'Heritage Texas Properties - Post Oak Park'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '7707 Cadenza Court',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '83',
#   'agent': 'Sam Sadeghi',
#   'office': 'Co/Max Holding & Realty Co.'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '8715 Andante Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '48',
#   'agent': 'Gregory Stessel',
#   'office': 'Leaping Cat Homes'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '7714 Allegro Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '102',
#   'agent': 'Lynn Collins',
#   'office': 'BHGRE Gary Greene'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9015 Rhapsody Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '92',
#   'agent': 'Katherine Weatherford',
#   'office': 'Exp Realty LLC'},
#  {'price': '305000'},
#  {'price': '370000'},
#  {'price': '385000'},
#  {'price': '238000'},
#  {'price': '289900'},
#  {'price': '399000'},
#  {'price': '309500'},
#  {'price': '347500'},
#  {'price': '305000'},
#  {'price': '325000'},
#  {'neighborhood': 'woodland trails west',
#   'address': '8419 Battle Plains Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '2',
#   'agent': 'Luz Hall',
#   'office': 'Nan & Company Properties'},
#  {'neighborhood': 'woodland trails west',
#   'address': '7435 Woodoak Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '4',
#   'agent': 'Lara Forssell',
#   'office': 'Keller Williams Realty The Woodlands'},
#  {'price': '215000'},
#  {'price': '159900'},
#  {'neighborhood': 'inwood pines',
#   'address': '3626 Abinger Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '4',
#   'agent': 'Lydia Flores',
#   'office': "Lydia's Fine Homes, LLC"},
#  {'neighborhood': 'inwood pines',
#   'address': '3622 Pine Ridge Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '20',
#   'agent': 'Carol Bonner',
#   'office': 'Champions Real Estate Group'},
#  {'neighborhood': 'inwood pines',
#   'address': '3423 Lemon Tree Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '24',
#   'agent': 'Michelle Pena',
#   'office': 'MetroPlus Realty'},
#  {'neighborhood': 'inwood pines',
#   'address': '3515 Black Locust Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '97',
#   'agent': 'Mechelle Williams',
#   'office': 'Exceed Realty'},
#  {'neighborhood': 'inwood pines',
#   'address': '3702 Black Locust Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '249',
#   'agent': 'Nining Maharddhika',
#   'office': 'Indostar Realty&Property Mgmt'},
#  {'price': '164000'},
#  {'price': '145000'},
#  {'price': '175000'},
#  {'price': '195000'},
#  {'price': '189900'},
#  {'neighborhood': 'independence heights',
#   'address': '318 E 37th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '12',
#   'agent': 'Lance Loken',
#   'office': 'Keller Williams Platinum'},
#  {'neighborhood': 'independence heights',
#   'address': '227 E 38th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '16',
#   'agent': 'Tyrone Mims',
#   'office': 'Realty Associates'},
#  {'neighborhood': 'independence heights',
#   'address': '310 E 35th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '22',
#   'agent': 'Richard Vegsund',
#   'office': 'CRC Real Estate Services'},
#  {'neighborhood': 'independence heights',
#   'address': '317 E 37th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '33',
#   'agent': 'Melyssa Wiseman',
#   'office': 'Wiseman Properties'},
#  {'neighborhood': 'independence heights',
#   'address': '7702 N Main St Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '48',
#   'agent': 'Lydia Cruz',
#   'office': 'Porchlight Realtors'},
#  {'neighborhood': 'independence heights',
#   'address': '324 E 39th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '50',
#   'agent': 'Martin Melchor',
#   'office': 'Keller Williams Houston Preferred'},
#  {'neighborhood': 'independence heights',
#   'address': '414 E 35th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '55',
#   'agent': 'Wayne Comer',
#   'office': '360 Realty & Management'},
#  {'neighborhood': 'independence heights',
#   'address': '326 E 39th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '69',
#   'agent': 'Martin Melchor',
#   'office': 'Keller Williams Houston Preferred'},
#  {'neighborhood': 'independence heights',
#   'address': '7904 N Main Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '64',
#   'agent': 'Martin Melchor',
#   'office': 'Keller Williams Houston Preferred'},
#  {'neighborhood': 'independence heights',
#   'address': '632 E 38th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '81',
#   'agent': 'Beatrice Bartlett',
#   'office': 'The Bartlett Real Estate Group'},
#  {'neighborhood': 'independence heights',
#   'address': '538 E 38th',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '86',
#   'agent': 'George Balla',
#   'office': 'Contemporary Real Estate LLC'},
#  {'neighborhood': 'independence heights',
#   'address': '536 E 38th',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '86',
#   'agent': 'George Balla',
#   'office': 'Contemporary Real Estate LLC'},
#  {'price': '200000'},
#  {'price': '210000'},
#  {'price': '120000'},
#  {'price': '339000'},
#  {'price': '339500'},
#  {'price': '339000'},
#  {'price': '190000'},
#  {'price': '319000'},
#  {'price': '275000'},
#  {'price': '149999'},
#  {'price': '239900'},
#  {'price': '239900'},
#  {'neighborhood': 'langwood',
#   'address': '8607 Friendship Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '6',
#   'agent': 'Melissa Huffman',
#   'office': 'Melissa Huffman'},
#  {'neighborhood': 'langwood',
#   'address': '3106 Maysel Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '9',
#   'agent': 'Michael McSorley',
#   'office': 'Keller Williams Memorial'},
#  {'neighborhood': 'langwood',
#   'address': '8546 Norton Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '6',
#   'agent': 'Maihuong Nguyen',
#   'office': 'Precious Realty & Mortgage'},
#  {'neighborhood': 'langwood',
#   'address': '6710 Clemson Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77092',
#   'days': '4',
#   'agent': 'Sharyn Short',
#   'office': 'Greenwood King Properties - Voss Office'},
#  {'neighborhood': 'langwood',
#   'address': '8418 Churchville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '38',
#   'agent': 'Armina Bradley',
#   'office': 'Realty Right'},
#  {'neighborhood': 'langwood',
#   'address': '8618 McDade Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '13',
#   'agent': 'Christi Baylor',
#   'office': 'UP Realty'},
#  {'neighborhood': 'langwood',
#   'address': '6527 Underhill Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77092',
#   'days': '20',
#   'agent': 'Nicholas Castaneda',
#   'office': 'American Property Realty, LLC'},
#  {'neighborhood': 'langwood',
#   'address': '8410 Sonneville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '67',
#   'agent': 'Roger Pallas-Nieto',
#   'office': 'REALM Real Estate Professionals - Galleria'},
#  {'neighborhood': 'langwood',
#   'address': '8466 Sonneville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '88',
#   'agent': 'Lydia Flores',
#   'office': "Lydia's Fine Homes, LLC"},
#  {'neighborhood': 'langwood',
#   'address': '6730 Thornwall Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77092',
#   'days': '10',
#   'agent': 'Gilbert Hernandez',
#   'office': 'Keller Williams Platinum'},
#  {'neighborhood': 'langwood',
#   'address': '8402 Churchville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '86',
#   'agent': 'Daniel Enriquez',
#   'office': 'Texas United Realty'},
#  {'price': '265100'},
#  {'price': '164962'},
#  {'price': '190000'},
#  {'price': '150000'},
#  {'price': '149900'},
#  {'price': '173250'},
#  {'price': '169000'},
#  {'price': '155000'},
#  {'price': '169000'},
#  {'price': '130000'},
#  {'price': '224900'},
#  {'neighborhood': 'kempwood',
#   'address': '3318 Springrock Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '15',
#   'agent': 'Ulises Bernardotti',
#   'office': 'Lone Star Realty'},
#  {'neighborhood': 'kempwood',
#   'address': '3351 Spring Valley Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '35',
#   'agent': "Scott O'Connell",
#   'office': "O'Connell Yarborough Prop"},
#  {'neighborhood': 'kempwood',
#   'address': '9706 Crestdale Circle',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '110',
#   'agent': 'Jinren Jim Lee',
#   'office': "Jim's Real Estate & Loan Svcs"},
#  {'neighborhood': 'kempwood',
#   'address': '3207 Springrock Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '244',
#   'agent': 'Joanne Naponic',
#   'office': 'Naponic Properties'},
#  {'price': '249000'},
#  {'price': '240000'},
#  {'price': '229000'},
#  {'price': '299000'},
#  {'neighborhood': 'home owned estates',
#   'address': '13433 Bandera Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '2',
#   'agent': 'Claudia Oakley',
#   'office': 'Keller Williams Realty Professionals'},
#  {'neighborhood': 'home owned estates',
#   'address': '13306 Joliet Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '5',
#   'agent': 'Blake Torrence',
#   'office': 'Coldwell Banker United,'},
#  {'neighborhood': 'home owned estates',
#   'address': '13371 Indianapolis Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '5',
#   'agent': 'Mirna Hernandez',
#   'office': 'Prime Realty Group'},
#  {'neighborhood': 'home owned estates',
#   'address': '806 Westmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '6',
#   'agent': 'Yuqiu Tang',
#   'office': 'Forever Realty, LLC'},
#  {'neighborhood': 'home owned estates',
#   'address': '13338 Force Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '8',
#   'agent': 'Brenda Hernandez',
#   'office': 'Keller Williams Memorial'},
#  {'neighborhood': 'home owned estates',
#   'address': '1007 Westmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '17',
#   'agent': 'Ellen Holt',
#   'office': 'RE/MAX Associates Northeast'},
#  {'neighborhood': 'home owned estates',
#   'address': '13359 Indianapolis Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '4',
#   'agent': 'Juvy Sudario',
#   'office': 'Prime Realty Group'},
#  {'neighborhood': 'home owned estates',
#   'address': '13355 Joliet Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '17',
#   'agent': 'Hernan Garcia',
#   'office': 'Turn Key Realty'},
#  {'neighborhood': 'home owned estates',
#   'address': '13318 Peoria Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '62',
#   'agent': 'Omar Scanu',
#   'office': 'RE/MAX 1st Source'},
#  {'neighborhood': 'home owned estates',
#   'address': '0 Mobile Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '184',
#   'agent': 'Jeff Denning',
#   'office': 'Turner Mangum,LLC'},
#  {'neighborhood': 'home owned estates',
#   'address': '1050 Glenalbyn Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '248',
#   'agent': 'Omar Scanu',
#   'office': 'RE/MAX 1st Source'},
#  {'neighborhood': 'home owned estates',
#   'address': '1126 Westmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '367',
#   'agent': 'Lou Rosas',
#   'office': 'RE/MAX Real Estate Assoc.'},
#  {'price': '159900'},
#  {'price': '94900'},
#  {'price': '129000'},
#  {'price': '208000'},
#  {'price': '164900'},
#  {'price': '119900'},
#  {'price': '89750'},
#  {'price': '149900'},
#  {'price': '45500'},
#  {'price': '160000'},
#  {'price': '24500'},
#  {'price': '265000'},
#  {'neighborhood': 'galenapark',
#   'address': '2507 15th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '1',
#   'agent': 'Erik Czirr',
#   'office': 'NextHome First Source'},
#  {'neighborhood': 'galenapark',
#   'address': '1107 Clinton Drive',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '17',
#   'agent': 'Ellen Holt',
#   'office': 'RE/MAX Associates Northeast'},
#  {'neighborhood': 'galenapark',
#   'address': '2516 6th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '17',
#   'agent': 'Denes Jafari',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions'},
#  {'neighborhood': 'galenapark',
#   'address': '2503 9th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '26',
#   'agent': 'Emelita Rhoades',
#   'office': 'Realty World Elite Group'},
#  {'neighborhood': 'galenapark',
#   'address': '2515 5th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '31',
#   'agent': 'Roosevelt Mucker',
#   'office': 'Generation Realty, LLC'},
#  {'neighborhood': 'galenapark',
#   'address': '2516 15th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '15',
#   'agent': 'Gloria Gutierrez',
#   'office': 'The Horizon Team'},
#  {'neighborhood': 'galenapark',
#   'address': '1501 Bank Drive',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '37',
#   'agent': 'Gloria Gutierrez',
#   'office': 'The Horizon Team'},
#  {'neighborhood': 'galenapark',
#   'address': '1905 11th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '110',
#   'agent': 'Thelma Ibarra',
#   'office': 'Houston Realty'},
#  {'neighborhood': 'galenapark',
#   'address': '2513 11th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '87',
#   'agent': 'Ana Gonzalez',
#   'office': 'Circa Real Estate LLC'},
#  {'neighborhood': 'galenapark',
#   'address': '1712 10th',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '110',
#   'agent': 'Belinda Malone',
#   'office': 'Keller Williams Memorial'},
#  {'neighborhood': 'galenapark',
#   'address': '1607 Clinton Drive',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '147',
#   'agent': 'Jose Ramon',
#   'office': 'Can-2 Realty'},
#  {'neighborhood': 'galenapark',
#   'address': '1911 11th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '70440018',
#   'agent': 'Felicia Beaudoin-Kyle',
#   'office': 'Coldwell Banker United, Realtors - Metropolitan'},
#  {'price': '144500'},
#  {'price': '275000'},
#  {'price': '145000'},
#  {'price': '189999'},
#  {'price': '99500'},
#  {'price': '169999'},
#  {'price': '129999'},
#  {'price': '120900'},
#  {'price': '142500'},
#  {'price': '108000'},
#  {'price': '379000'},
#  {'price': '99700'},
#  {'neighborhood': 'braeburn glen',
#   'address': '8811 Imogene Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77074',
#   'days': '5',
#   'agent': 'Nguyen Wilson',
#   'office': 'Wilson Realty & Inv Grp, LLC'},
#  {'neighborhood': 'braeburn glen',
#   'address': '8711 Reamer Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77074',
#   'days': '18',
#   'agent': 'Wayne Comer',
#   'office': '360 Realty & Management'},
#  {'neighborhood': 'braeburn glen',
#   'address': '8706 Jason Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77074',
#   'days': '169',
#   'agent': 'Nguyen Wilson',
#   'office': 'Wilson Realty & Inv Grp, LLC'},
#  {'price': '135000'},
#  {'price': '215000'},
#  {'price': '219000'},
#  {'neighborhood': 'highland shores',
#   'address': 'LT 27 Highland Shores Road',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '112',
#   'agent': 'Veronica Gamez',
#   'office': 'Coldwell Banker United, REALTORS- Baytown'},
#  {'neighborhood': 'highland shores',
#   'address': '00 Shorewick Drive',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '272',
#   'agent': 'Emiliano Nino',
#   'office': 'Mission Realty'},
#  {'neighborhood': 'highland shores',
#   'address': '0 Shorewick Drive',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '272',
#   'agent': 'Emiliano Nino',
#   'office': 'Mission Realty'},
#  {'neighborhood': 'highland shores',
#   'address': '2425 Shorewick Drive',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '173',
#   'agent': 'Emiliano Nino',
#   'office': 'Mission Realty'},
#  {'price': '19900'},
#  {'price': '75000'},
#  {'price': '75000'},
#  {'price': '250000'},
#  {'neighborhood': 'san jacinto river estates',
#   'address': '17404 Moreland Drive',
#   'city': 'Channelview',
#   'state': 'TX',
#   'zip': '77530',
#   'days': '29',
#   'agent': 'Dessiree Macias',
#   'office': 'Keller Williams Realty Metropolitan'},
#  {'price': '250000'},
#  {'neighborhood': 'bliss meadows',
#   'address': '5816 Melinda Lane',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '9',
#   'agent': 'Renee Taylor',
#   'office': 'Prince Properties, LLC'},
#  {'neighborhood': 'bliss meadows',
#   'address': '5802 Lucy Lane',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '21',
#   'agent': 'Lance Loken',
#   'office': 'Keller Williams Platinum'},
#  {'neighborhood': 'bliss meadows',
#   'address': '5816 S Meadow Drive',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '46',
#   'agent': 'Ozzie Ramirez',
#   'office': 'Keller Williams Realty'},
#  {'price': '199900'},
#  {'price': '150000'},
#  {'price': '190000'},
#  {'neighborhood': 'crest haven estates',
#   'address': '6419 Olson Lane',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '3',
#   'agent': 'James Toler',
#   'office': 'Logos Investment Properties'},
#  {'price': '155000'},
#  {'neighborhood': 'spenwick place',
#   'address': '9414 Spencer Hwy Highway',
#   'city': 'La Porte',
#   'state': 'TX',
#   'zip': '77571',
#   'days': '96',
#   'agent': 'Mary Carrizal',
#   'office': 'Main Properties'},
#  {'neighborhood': 'spenwick place',
#   'address': '9406 Spencer Hwy Highway',
#   'city': 'La Porte',
#   'state': 'TX',
#   'zip': '77571',
#   'days': '96',
#   'agent': 'Mary Carrizal',
#   'office': 'Main Properties'},
#  {'price': '199900'},
#  {'price': '796599'},
#  {'neighborhood': 'sagemont',
#   'address': '10919 Sagecanyon Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '3',
#   'agent': 'Nusrat Ghafoor',
#   'office': 'Walzel Properties'},
#  {'neighborhood': 'sagemont',
#   'address': '11010 Sagepark Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '5',
#   'agent': 'Amanda Escamilla',
#   'office': 'JLA Realty'},
#  {'neighborhood': 'sagemont',
#   'address': '11323 Sagevale Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '9',
#   'agent': 'Sonal Shah',
#   'office': 'REALM Real Estate Professionals - Sugar Land'},
#  {'neighborhood': 'sagemont',
#   'address': '11026 Sagemeadow Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '10',
#   'agent': 'Robert Roland',
#   'office': 'Realty Associates'},
#  {'neighborhood': 'sagemont',
#   'address': '11118 Sagedowne Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '5',
#   'agent': 'Sebastian Ponce',
#   'office': 'Ponce Realty & Investments'},
#  {'neighborhood': 'sagemont',
#   'address': '18922 Picnic Pavilion Court',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77433',
#   'days': '18',
#   'agent': 'Richard Hale',
#   'office': 'Perry Development Management'},
#  {'neighborhood': 'sagemont',
#   'address': '10339 Sagerock Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '18',
#   'agent': 'Rebecca Casey',
#   'office': 'Casey Castles, LLC'},
#  {'neighborhood': 'sagemont',
#   'address': '10818 Sageleaf Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '19',
#   'agent': 'Mark Benoit',
#   'office': 'RE/MAX 1st Source'},
#  {'neighborhood': 'sagemont',
#   'address': '10402 Sagedowne Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '5',
#   'agent': 'Davian Walker',
#   'office': "Houston's Choice Realty"},
#  {'neighborhood': 'sagemont',
#   'address': '10910 Sagetrail Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '30',
#   'agent': 'Yesenia Guerra',
#   'office': 'CJM Realty Advisors'},
#  {'neighborhood': 'sagemont',
#   'address': '11602 Sagedowne Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '34',
#   'agent': 'Yaneth Zaragosa',
#   'office': 'Strada'},
#  {'neighborhood': 'sagemont',
#   'address': '10835 Sageburrow Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '34',
#   'agent': 'Jane NgaDung Nguyen',
#   'office': 'Alpha, REALTORS'},
#  {'price': '224500'},
#  {'price': '175000'},
#  {'price': '199990'},
#  {'price': '220000'},
#  {'price': '199900'},
#  {'price': '424900'},
#  {'price': '148900'},
#  {'price': '169900'},
#  {'price': '199000'},
#  {'price': '204999'},
#  {'price': '195000'},
#  {'price': '225990'}]

# %%
import os
import time
import csv
import requests
from bs4 import BeautifulSoup
from pprint import pprint
from urllib import parse
import re 
from datetime import datetime
import schedule
import threading
import itertools
import ast
# from task import homes_comparison
import json
import sys

def har_homes():
    urls = ["https://www.har.com/sagemont/homes-for-sale/3666?sort=listdate+desc",
            "https://www.har.com/riverwood-estates/homes-for-sale/2377?sort=listdate+desc",
            "https://www.har.com/forest-shadows/homes-for-sale/4585?sort=listdate+desc",
           "https://www.har.com/aldine-estates/homes-for-sale/1917?sort=listdate+desc"
           "https://www.har.com/greenbranch/homes-for-sale/1921?sort=listdate+desc",
           "https://www.har.com/castlewood/homes-for-sale/2078?sort=listdate+desc",
           "https://www.har.com/bamwood-terrace/homes-for-sale/3693?sort=listdate+desc",
           "https://www.har.com/lynwood-estates/homes-for-sale/5152?sort=listdate+desc",
           "https://www.har.com/parkwood-estates-77032/homes-for-sale/1911?sort=listdate+desc",
            "https://www.har.com/humble-road-place/homes-for-sale/5738?sort=listdate+desc",
            "https://www.har.com/langley-road-place/homes-for-sale/3838?sort=listdate+desc",
            "https://www.har.com/sandbar-estates/homes-for-sale/9033?sort=listdate+desc",
            "https://www.har.com/houston-hot-wells/homes-for-sale/6115?sort=listdate+desc",
            "https://www.har.com/lake-cypress-estates-u_r/homes-for-sale/6010?sort=listdate+desc",
            "https://www.har.com/bammel-forest/homes-for-sale/2893?sort=listdate+desc",
            "https://www.har.com/airline-farms/homes-for-sale/2045?sort=listdate+desc",
            "https://www.har.com/norchester/homes-for-sale/2949?sort=listdate+desc",
            "https://www.har.com/grantwood/homes-for-sale/6022?sort=listdate+desc",
            "https://www.har.com/windwood-extn-u_r/homes-for-sale/6015?sort=listdate+desc",
            "https://www.har.com/coles-crossing/homes-for-sale/6066?sort=listdate+desc",
            "https://www.har.com/woodwind-lakes/homes-for-sale/2113?sort=listdate+desc",
            "https://www.har.com/woodland-trails-west/homes-for-sale/2103?sort=listdate+desc",
            "https://www.har.com/inwood-pines/homes-for-sale/3649?sort=listdate+desc",
            "https://www.har.com/independence-heights/homes-for-sale/1049?sort=listdate+desc",
            "https://www.har.com/langwood/homes-for-sale/3775?sort=listdate+desc",
            "https://www.har.com/kempwood/homes-for-sale/3355?sort=listdate+desc",
            "https://www.har.com/home-owned-estates/homes-for-sale/947?sort=listdate+desc",
            "https://www.har.com/galenapark/realestate/for_sale?sort=listdate+desc",
            "https://www.har.com/braeburn-glen/homes-for-sale/3076?sort=listdate+desc",
            "https://www.har.com/highland-shores/homes-for-sale/9027?sort=listdate+desc",
            "https://www.har.com/san-jacinto-river-estates/homes-for-sale/8074?sort=listdate+desc",
            "https://www.har.com/bliss-meadows/homes-for-sale/7292?sort=listdate+desc",
            "https://www.har.com/bramley/homes-for-sale/7249?sort=listdate+desc",
            "https://www.har.com/crest-haven-estates/homes-for-sale/7290?sort=listdate+desc",
            "https://www.har.com/spenwick-place/homes-for-sale/9397?sort=listdate+desc"]

    all_homes = []

    for url in urls:
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'lxml')
        homes = soup.find_all("div", class_="prop_list")[0]
        neighborhood = url.split('/')[3].replace('-',' ')
        if soup.find_all("h2", {"class":"charcole reguler"}):
            pass
        
        for home in homes.find_all('div', class_= 'prop_item'):
            try:
                    info = home.find(class_= 'mpi_info')
#                     print(info)
                    full_address = info.find_all('a', class_= 'address')[0].text
                    split_address = full_address.split(',')
                    use_split_address = split_address[0].strip()
                    use_split_city = split_address[1].strip()
                    state_zip = split_address[2].split(' ')
                    use_state = state_zip[1].strip()
                    use_zip = state_zip[2].strip()
                    pull_right_selection = info.find('div', class_= "pull-right")
                    use_days = pull_right_selection.find_all('span', class_= 'bold')[0].text
            
                    use_agent = info.find_all('a', class_='bold')[0].text.strip()
                    use_office = info.find_all('a', class_= 'bold')[1].text.strip()
                    #fix the use days code to reflect correct info

                    home_info=  {
                        "neighborhood": neighborhood,
                        "address": use_split_address,
                        "city": use_split_city,
                        "state": use_state,
                        "zip": use_zip,
                        "days": use_days,
                        "agent": use_agent,
                        "office": use_office}
                    
                    
                    price_div = home.find_all(class_='price')
                    price_div= price_div[0]
                    if price_div.find('img'):
                        price_div.find('img').decompose()

                   
                    price_list = price_div.text.replace('$', '').replace(',','').strip('][')
                    new_price = price_list[2:8].strip().split('/n')[0]
                    home_info["price"] = new_price

                    
                    
                    all_homes.append(home_info)


            except:
                print("No results given for " + url)
                continue




    return all_homes



with open('scraped_homes.json', 'w') as output_file:
    json.dump(har_homes(), output_file)
    

har_homes()

# def compare():
#     homes_comparison(scraped_homes = har_homes())
#     # print("banana")

# def threader(job_func):
#     job_thread = threading.Thread(target=job_func)
#     job_thread.start()

#     schedule.every(180).seconds.do(threader, compare)

# def main():    
#     schedule.run_pending()
#     time.sleep(1)
# Out:
# No results given for https://www.har.com/coles-crossing/homes-for-sale/6066?sort=listdate+desc
# No results given for https://www.har.com/galenapark/realestate/for_sale?sort=listdate+desc
# No results given for https://www.har.com/coles-crossing/homes-for-sale/6066?sort=listdate+desc
# No results given for https://www.har.com/galenapark/realestate/for_sale?sort=listdate+desc
# [{'neighborhood': 'sagemont',
#   'address': '10919 Sagecanyon Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '3',
#   'agent': 'Nusrat Ghafoor',
#   'office': 'Walzel Properties',
#   'price': '224500'},
#  {'neighborhood': 'sagemont',
#   'address': '11010 Sagepark Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '5',
#   'agent': 'Amanda Escamilla',
#   'office': 'JLA Realty',
#   'price': '175000'},
#  {'neighborhood': 'sagemont',
#   'address': '11323 Sagevale Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '9',
#   'agent': 'Sonal Shah',
#   'office': 'REALM Real Estate Professionals - Sugar Land',
#   'price': '199990'},
#  {'neighborhood': 'sagemont',
#   'address': '11026 Sagemeadow Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '10',
#   'agent': 'Robert Roland',
#   'office': 'Realty Associates',
#   'price': '220000'},
#  {'neighborhood': 'sagemont',
#   'address': '11118 Sagedowne Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '5',
#   'agent': 'Sebastian Ponce',
#   'office': 'Ponce Realty & Investments',
#   'price': '199900'},
#  {'neighborhood': 'sagemont',
#   'address': '18922 Picnic Pavilion Court',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77433',
#   'days': '18',
#   'agent': 'Richard Hale',
#   'office': 'Perry Development Management',
#   'price': '424900'},
#  {'neighborhood': 'sagemont',
#   'address': '10339 Sagerock Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '18',
#   'agent': 'Rebecca Casey',
#   'office': 'Casey Castles, LLC',
#   'price': '148900'},
#  {'neighborhood': 'sagemont',
#   'address': '10818 Sageleaf Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '19',
#   'agent': 'Mark Benoit',
#   'office': 'RE/MAX 1st Source',
#   'price': '169900'},
#  {'neighborhood': 'sagemont',
#   'address': '10402 Sagedowne Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '5',
#   'agent': 'Davian Walker',
#   'office': "Houston's Choice Realty",
#   'price': '199000'},
#  {'neighborhood': 'sagemont',
#   'address': '10910 Sagetrail Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '30',
#   'agent': 'Yesenia Guerra',
#   'office': 'CJM Realty Advisors',
#   'price': '204999'},
#  {'neighborhood': 'sagemont',
#   'address': '11602 Sagedowne Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '34',
#   'agent': 'Yaneth Zaragosa',
#   'office': 'Strada',
#   'price': '195000'},
#  {'neighborhood': 'sagemont',
#   'address': '10835 Sageburrow Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77089',
#   'days': '34',
#   'agent': 'Jane NgaDung Nguyen',
#   'office': 'Alpha, REALTORS',
#   'price': '225990'},
#  {'neighborhood': 'riverwood estates',
#   'address': '6106 Great Oaks Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77050',
#   'days': '15',
#   'agent': 'Marisa Lopez',
#   'office': 'Near Town Properties',
#   'price': '144700'},
#  {'neighborhood': 'forest shadows',
#   'address': '21807 Forest Glade Drive',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '24',
#   'agent': 'Jodi Manfred',
#   'office': 'JLA Realty',
#   'price': '199000'},
#  {'neighborhood': 'forest shadows',
#   'address': '4706 Broadmark Lane',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '66',
#   'agent': 'Cellina Stokes',
#   'office': 'Crowne Realty',
#   'price': '171500'},
#  {'neighborhood': 'forest shadows',
#   'address': '4602 Fieldwick Lane',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '80',
#   'agent': 'Michael Thiltgen',
#   'office': 'Greenbriar Real Estate Service',
#   'price': '189900'},
#  {'neighborhood': 'forest shadows',
#   'address': '21802 Pine Cone Drive',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '81',
#   'agent': 'Katherine Ware',
#   'office': 'Irie Properties, LLC',
#   'price': '239900'},
#  {'neighborhood': 'forest shadows',
#   'address': '4503 Clairfield Lane',
#   'city': 'Humble',
#   'state': 'TX',
#   'zip': '77338',
#   'days': '122',
#   'agent': 'Rick Raymor',
#   'office': 'RE/MAX Universal',
#   'price': '259500'},
#  {'neighborhood': 'aldine estates',
#   'address': '15202 Claypool Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77032',
#   'days': '111',
#   'agent': 'Rosa Gonzalez',
#   'office': 'REALM Real Estate Professionals - North Houston',
#   'price': '650000'},
#  {'neighborhood': 'castlewood',
#   'address': '2418 Toyah Avenue',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '15',
#   'agent': 'Paula Plata',
#   'office': 'Keller Williams Memorial',
#   'price': '175000'},
#  {'neighborhood': 'castlewood',
#   'address': '2517 Woodgate Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '109',
#   'agent': 'Gina Lopez',
#   'office': 'Loft Realty',
#   'price': '200000'},
#  {'neighborhood': 'castlewood',
#   'address': '2802 Rosebury Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '131',
#   'agent': 'Esmeralda Herrera',
#   'office': 'Century 21 Hardee-Team Realty',
#   'price': '159000'},
#  {'neighborhood': 'castlewood',
#   'address': '2615 Balmorhea Avenue',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77039',
#   'days': '169',
#   'agent': 'Mary Villarreal',
#   'office': 'Ability Real Estate',
#   'price': '125000'},
#  {'neighborhood': 'lynwood estates',
#   'address': '906 Lynwood Road',
#   'city': 'Spring',
#   'state': 'TX',
#   'zip': '77373',
#   'days': '17',
#   'agent': 'Rania Hanania',
#   'office': 'JLA Realty',
#   'price': '255000'},
#  {'neighborhood': 'lynwood estates',
#   'address': '1311 Lynwood Road',
#   'city': 'Spring',
#   'state': 'TX',
#   'zip': '77373',
#   'days': '4',
#   'agent': 'Gidget Sauceda',
#   'office': 'RE/MAX Universal',
#   'price': '189900'},
#  {'neighborhood': 'parkwood estates 77032',
#   'address': '14301 Lee Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77032',
#   'days': '164',
#   'agent': 'Maria Salazar',
#   'office': 'Nautilus Real Estate, Ltd',
#   'price': '184900'},
#  {'neighborhood': 'lake cypress estates u_r',
#   'address': '13200 Huffmeister Road',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '20',
#   'agent': 'Amjad Mushtaq',
#   'office': 'Fast Homes',
#   'price': '199000'},
#  {'neighborhood': 'lake cypress estates u_r',
#   'address': '0 Maxwell Road',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '84',
#   'agent': 'Kristi Grimes',
#   'office': 'eXp Realty LLC',
#   'price': '100000'},
#  {'neighborhood': 'lake cypress estates u_r',
#   'address': '13026 Maxwell Road',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '244',
#   'agent': 'Ryan Jockers',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions',
#   'price': '384990'},
#  {'neighborhood': 'bammel forest',
#   'address': '16314 Waycreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '3',
#   'agent': 'Arlene Simmons',
#   'office': 'RE/MAX Integrity',
#   'price': '219000'},
#  {'neighborhood': 'bammel forest',
#   'address': '2511 Bycreek Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '8',
#   'agent': 'Lisa Shackleton',
#   'office': 'JLA Realty',
#   'price': '210000'},
#  {'neighborhood': 'bammel forest',
#   'address': '2618 Colwell Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '23',
#   'agent': 'Gay Perque',
#   'office': 'RE/MAX Vintage',
#   'price': '189500'},
#  {'neighborhood': 'bammel forest',
#   'address': '16211 Creeksouth Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '25',
#   'agent': 'Cameron Namazi',
#   'office': 'Summit Realty',
#   'price': '214900'},
#  {'neighborhood': 'bammel forest',
#   'address': '16523 Waycreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '28',
#   'agent': 'Yvonne Chauvin',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene',
#   'price': '230000'},
#  {'neighborhood': 'bammel forest',
#   'address': '2610 Creekhickory Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '60',
#   'agent': 'Rick Shelton',
#   'office': 'The Horizon Team',
#   'price': '241990'},
#  {'neighborhood': 'bammel forest',
#   'address': '2402 Encreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '65',
#   'agent': 'Rick Shelton',
#   'office': 'The Horizon Team',
#   'price': '272500'},
#  {'neighborhood': 'bammel forest',
#   'address': '2503 Encreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '43',
#   'agent': 'Angela Muniz',
#   'office': 'Champions Real Estate Group',
#   'price': '249900'},
#  {'neighborhood': 'bammel forest',
#   'address': '2319 Encreek Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '235',
#   'agent': 'Rick Shelton',
#   'office': 'The Horizon Team',
#   'price': '244990'},
#  {'neighborhood': 'bammel forest',
#   'address': '16911 Creeksouth Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77068',
#   'days': '119',
#   'agent': 'Cecilia Hernandez',
#   'office': 'Champions Real Estate Group',
#   'price': '289900'},
#  {'neighborhood': 'airline farms',
#   'address': '9501 North Freeway',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77037',
#   'days': '689',
#   'agent': 'Benito Armas',
#   'office': 'Armas Realty',
#   'price': '750000'},
#  {'neighborhood': 'norchester',
#   'address': '10530 Normont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '18',
#   'agent': 'Alfonso Parodi',
#   'office': 'Realty Associates',
#   'price': '290000'},
#  {'neighborhood': 'norchester',
#   'address': '10522 Idlebrook Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '24',
#   'agent': 'Jose Portillo',
#   'office': 'Champions Real Estate Group',
#   'price': '279700'},
#  {'neighborhood': 'norchester',
#   'address': '10722 Fawnview Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '23',
#   'agent': 'Dee Pardue',
#   'office': 'NextHome Realty Center',
#   'price': '224500'},
#  {'neighborhood': 'norchester',
#   'address': '10906 Archmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '37',
#   'agent': 'J.P. Bowers',
#   'office': 'RE/MAX Westside, REALTORS',
#   'price': '275000'},
#  {'neighborhood': 'norchester',
#   'address': '10723 Brentway Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '5',
#   'agent': 'Timothy Merritt',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions',
#   'price': '236000'},
#  {'neighborhood': 'norchester',
#   'address': '10530 Glenway Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '15',
#   'agent': 'Angelica Fernandez',
#   'office': 'RE/MAX Signature',
#   'price': '279999'},
#  {'neighborhood': 'norchester',
#   'address': '10515 Laneview Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '52',
#   'agent': 'Rebecca Robertson',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene',
#   'price': '247000'},
#  {'neighborhood': 'norchester',
#   'address': '10818 Elmdale Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '60',
#   'agent': 'Albert Tapia',
#   'office': 'Champions Real Estate Group',
#   'price': '254800'},
#  {'neighborhood': 'norchester',
#   'address': '10511 Moorcreek',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '77',
#   'agent': 'Lisa Pittman',
#   'office': 'NextHome Realty Center',
#   'price': '255000'},
#  {'neighborhood': 'norchester',
#   'address': '10610 Normont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '77',
#   'agent': 'Karen Davis',
#   'office': 'Karen Davis Properties',
#   'price': '34900'},
#  {'neighborhood': 'norchester',
#   'address': '10803 Fawnview Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '100',
#   'agent': 'Lex Parker',
#   'office': 'MHW Real Estate, Inc.',
#   'price': '185000'},
#  {'neighborhood': 'norchester',
#   'address': '10534 Jaycreek Drive',
#   'city': 'North Houston',
#   'state': 'TX',
#   'zip': '77070',
#   'days': '113',
#   'agent': 'Chuck Pounds',
#   'office': 'REALM Real Estate Professionals - North Houston',
#   'price': '299500'},
#  {'neighborhood': 'windwood extn u_r',
#   'address': '11934 Deep Woods Drive Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '143',
#   'agent': 'Miriam Ackley',
#   'office': 'On the Market Realty, Inc',
#   'price': '399999'},
#  {'neighborhood': 'coles crossing',
#   'address': '13927 Sherburn Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '9',
#   'agent': 'Raymond LaFuente',
#   'office': 'RE/MAX Integrity',
#   'price': '299999'},
#  {'neighborhood': 'coles crossing',
#   'address': '15839 Cypress Hall Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '10',
#   'agent': 'David Flory',
#   'office': 'RE/MAX Universal',
#   'price': '300000'},
#  {'neighborhood': 'coles crossing',
#   'address': '14231 Northface Manor Court',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '4',
#   'agent': 'Terri Garza',
#   'office': 'NextHome Realty Center',
#   'price': '499000'},
#  {'neighborhood': 'coles crossing',
#   'address': '13823 Sherburn Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '5',
#   'agent': 'Tracy Hughes',
#   'office': 'Coldwell Banker United, Realtors - CY Fair',
#   'price': '305000'},
#  {'neighborhood': 'coles crossing',
#   'address': '13714 Sherburn Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '12',
#   'agent': 'Astrid West',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene',
#   'price': '269900'},
#  {'neighborhood': 'coles crossing',
#   'address': '13526 Greenwood Manor Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '2',
#   'agent': 'Amy Lippincott',
#   'office': 'Keller Williams Platinum',
#   'price': '475000'},
#  {'neighborhood': 'coles crossing',
#   'address': '16306 Wytchwood Circle',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '13',
#   'agent': 'Jeanne Skinner',
#   'office': 'Walzel Properties - Corporate Office',
#   'price': '278000'},
#  {'neighborhood': 'coles crossing',
#   'address': '14035 Fosters Creek Drive Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '36',
#   'agent': 'Tanya Bailey',
#   'office': 'Texas United Realty',
#   'price': '337000'},
#  {'neighborhood': 'coles crossing',
#   'address': '13927 Prospect Point Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '15',
#   'agent': 'Tanya Langner',
#   'office': 'Levine & Co. Real Estate LLC',
#   'price': '315000'},
#  {'neighborhood': 'coles crossing',
#   'address': '13415 N Bend Landing',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '18',
#   'agent': 'Rochelle Barrow',
#   'office': 'Berkshire Hathaway HomeServices Anderson Properties',
#   'price': '519000'},
#  {'neighborhood': 'coles crossing',
#   'address': '14646 Bergenia Drive',
#   'city': 'Cypress',
#   'state': 'TX',
#   'zip': '77429',
#   'days': '2',
#   'agent': 'Melanie Dubendorff',
#   'office': 'Keller Williams Platinum',
#   'price': '234913'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '8114 Clarion Way',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '1',
#   'agent': 'Colleen Sherlock',
#   'office': 'Greenwood King Properties',
#   'price': '305000'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '7907 Ensemble Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '16',
#   'agent': 'Lance Loken',
#   'office': 'Keller Williams Platinum',
#   'price': '370000'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '8018 Sonata Court',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '6',
#   'agent': 'Lynn Collins',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions',
#   'price': '385000'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9346 Adagio Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '24',
#   'agent': 'Lynn Collins',
#   'office': 'BHGRE Gary Greene',
#   'price': '238000'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9223 Symphonic Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '35',
#   'agent': 'Sonia Cousins',
#   'office': 'RE/MAX Fine Properties',
#   'price': '289900'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9106 Symphonic Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '27',
#   'agent': 'Paula Forno-Engler',
#   'office': 'Heritage Texas Properties - Post Oak Park',
#   'price': '399000'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '7707 Cadenza Court',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '83',
#   'agent': 'Sam Sadeghi',
#   'office': 'Co/Max Holding & Realty Co.',
#   'price': '309500'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '8715 Andante Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '48',
#   'agent': 'Gregory Stessel',
#   'office': 'Leaping Cat Homes',
#   'price': '347500'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '7714 Allegro Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '102',
#   'agent': 'Lynn Collins',
#   'office': 'BHGRE Gary Greene',
#   'price': '305000'},
#  {'neighborhood': 'woodwind lakes',
#   'address': '9015 Rhapsody Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '92',
#   'agent': 'Katherine Weatherford',
#   'office': 'Exp Realty LLC',
#   'price': '325000'},
#  {'neighborhood': 'woodland trails west',
#   'address': '8419 Battle Plains Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '2',
#   'agent': 'Luz Hall',
#   'office': 'Nan & Company Properties',
#   'price': '215000'},
#  {'neighborhood': 'woodland trails west',
#   'address': '7435 Woodoak Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77040',
#   'days': '4',
#   'agent': 'Lara Forssell',
#   'office': 'Keller Williams Realty The Woodlands',
#   'price': '159900'},
#  {'neighborhood': 'inwood pines',
#   'address': '3626 Abinger Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '4',
#   'agent': 'Lydia Flores',
#   'office': "Lydia's Fine Homes, LLC",
#   'price': '164000'},
#  {'neighborhood': 'inwood pines',
#   'address': '3622 Pine Ridge Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '20',
#   'agent': 'Carol Bonner',
#   'office': 'Champions Real Estate Group',
#   'price': '145000'},
#  {'neighborhood': 'inwood pines',
#   'address': '3423 Lemon Tree Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '24',
#   'agent': 'Michelle Pena',
#   'office': 'MetroPlus Realty',
#   'price': '175000'},
#  {'neighborhood': 'inwood pines',
#   'address': '3515 Black Locust Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '97',
#   'agent': 'Mechelle Williams',
#   'office': 'Exceed Realty',
#   'price': '195000'},
#  {'neighborhood': 'inwood pines',
#   'address': '3702 Black Locust Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77088',
#   'days': '249',
#   'agent': 'Nining Maharddhika',
#   'office': 'Indostar Realty&Property Mgmt',
#   'price': '189900'},
#  {'neighborhood': 'independence heights',
#   'address': '318 E 37th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '12',
#   'agent': 'Lance Loken',
#   'office': 'Keller Williams Platinum',
#   'price': '200000'},
#  {'neighborhood': 'independence heights',
#   'address': '227 E 38th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '16',
#   'agent': 'Tyrone Mims',
#   'office': 'Realty Associates',
#   'price': '210000'},
#  {'neighborhood': 'independence heights',
#   'address': '310 E 35th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '22',
#   'agent': 'Richard Vegsund',
#   'office': 'CRC Real Estate Services',
#   'price': '120000'},
#  {'neighborhood': 'independence heights',
#   'address': '317 E 37th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '33',
#   'agent': 'Melyssa Wiseman',
#   'office': 'Wiseman Properties',
#   'price': '339000'},
#  {'neighborhood': 'independence heights',
#   'address': '7702 N Main St Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '48',
#   'agent': 'Lydia Cruz',
#   'office': 'Porchlight Realtors',
#   'price': '339500'},
#  {'neighborhood': 'independence heights',
#   'address': '324 E 39th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '50',
#   'agent': 'Martin Melchor',
#   'office': 'Keller Williams Houston Preferred',
#   'price': '339000'},
#  {'neighborhood': 'independence heights',
#   'address': '414 E 35th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '55',
#   'agent': 'Wayne Comer',
#   'office': '360 Realty & Management',
#   'price': '190000'},
#  {'neighborhood': 'independence heights',
#   'address': '326 E 39th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77018',
#   'days': '69',
#   'agent': 'Martin Melchor',
#   'office': 'Keller Williams Houston Preferred',
#   'price': '319000'},
#  {'neighborhood': 'independence heights',
#   'address': '7904 N Main Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '64',
#   'agent': 'Martin Melchor',
#   'office': 'Keller Williams Houston Preferred',
#   'price': '275000'},
#  {'neighborhood': 'independence heights',
#   'address': '632 E 38th Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '81',
#   'agent': 'Beatrice Bartlett',
#   'office': 'The Bartlett Real Estate Group',
#   'price': '149999'},
#  {'neighborhood': 'independence heights',
#   'address': '538 E 38th',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '86',
#   'agent': 'George Balla',
#   'office': 'Contemporary Real Estate LLC',
#   'price': '239900'},
#  {'neighborhood': 'independence heights',
#   'address': '536 E 38th',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77022',
#   'days': '86',
#   'agent': 'George Balla',
#   'office': 'Contemporary Real Estate LLC',
#   'price': '239900'},
#  {'neighborhood': 'langwood',
#   'address': '8607 Friendship Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '6',
#   'agent': 'Melissa Huffman',
#   'office': 'Melissa Huffman',
#   'price': '265100'},
#  {'neighborhood': 'langwood',
#   'address': '3106 Maysel Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '9',
#   'agent': 'Michael McSorley',
#   'office': 'Keller Williams Memorial',
#   'price': '164962'},
#  {'neighborhood': 'langwood',
#   'address': '8546 Norton Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '6',
#   'agent': 'Maihuong Nguyen',
#   'office': 'Precious Realty & Mortgage',
#   'price': '190000'},
#  {'neighborhood': 'langwood',
#   'address': '6710 Clemson Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77092',
#   'days': '4',
#   'agent': 'Sharyn Short',
#   'office': 'Greenwood King Properties - Voss Office',
#   'price': '150000'},
#  {'neighborhood': 'langwood',
#   'address': '8418 Churchville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '38',
#   'agent': 'Armina Bradley',
#   'office': 'Realty Right',
#   'price': '149900'},
#  {'neighborhood': 'langwood',
#   'address': '8618 McDade Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '13',
#   'agent': 'Christi Baylor',
#   'office': 'UP Realty',
#   'price': '173250'},
#  {'neighborhood': 'langwood',
#   'address': '6527 Underhill Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77092',
#   'days': '20',
#   'agent': 'Nicholas Castaneda',
#   'office': 'American Property Realty, LLC',
#   'price': '169000'},
#  {'neighborhood': 'langwood',
#   'address': '8410 Sonneville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '67',
#   'agent': 'Roger Pallas-Nieto',
#   'office': 'REALM Real Estate Professionals - Galleria',
#   'price': '155000'},
#  {'neighborhood': 'langwood',
#   'address': '8466 Sonneville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '88',
#   'agent': 'Lydia Flores',
#   'office': "Lydia's Fine Homes, LLC",
#   'price': '169000'},
#  {'neighborhood': 'langwood',
#   'address': '6730 Thornwall Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77092',
#   'days': '10',
#   'agent': 'Gilbert Hernandez',
#   'office': 'Keller Williams Platinum',
#   'price': '130000'},
#  {'neighborhood': 'langwood',
#   'address': '8402 Churchville Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '86',
#   'agent': 'Daniel Enriquez',
#   'office': 'Texas United Realty',
#   'price': '224900'},
#  {'neighborhood': 'kempwood',
#   'address': '3318 Springrock Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '15',
#   'agent': 'Ulises Bernardotti',
#   'office': 'Lone Star Realty',
#   'price': '249000'},
#  {'neighborhood': 'kempwood',
#   'address': '3351 Spring Valley Road',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '35',
#   'agent': "Scott O'Connell",
#   'office': "O'Connell Yarborough Prop",
#   'price': '240000'},
#  {'neighborhood': 'kempwood',
#   'address': '9706 Crestdale Circle',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '110',
#   'agent': 'Jinren Jim Lee',
#   'office': "Jim's Real Estate & Loan Svcs",
#   'price': '229000'},
#  {'neighborhood': 'kempwood',
#   'address': '3207 Springrock Lane',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77080',
#   'days': '244',
#   'agent': 'Joanne Naponic',
#   'office': 'Naponic Properties',
#   'price': '299000'},
#  {'neighborhood': 'home owned estates',
#   'address': '13433 Bandera Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '2',
#   'agent': 'Claudia Oakley',
#   'office': 'Keller Williams Realty Professionals',
#   'price': '159900'},
#  {'neighborhood': 'home owned estates',
#   'address': '13306 Joliet Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '5',
#   'agent': 'Blake Torrence',
#   'office': 'Coldwell Banker United,',
#   'price': '94900'},
#  {'neighborhood': 'home owned estates',
#   'address': '13371 Indianapolis Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '5',
#   'agent': 'Mirna Hernandez',
#   'office': 'Prime Realty Group',
#   'price': '129000'},
#  {'neighborhood': 'home owned estates',
#   'address': '806 Westmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '6',
#   'agent': 'Yuqiu Tang',
#   'office': 'Forever Realty, LLC',
#   'price': '208000'},
#  {'neighborhood': 'home owned estates',
#   'address': '13338 Force Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '8',
#   'agent': 'Brenda Hernandez',
#   'office': 'Keller Williams Memorial',
#   'price': '164900'},
#  {'neighborhood': 'home owned estates',
#   'address': '1007 Westmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '17',
#   'agent': 'Ellen Holt',
#   'office': 'RE/MAX Associates Northeast',
#   'price': '119900'},
#  {'neighborhood': 'home owned estates',
#   'address': '13359 Indianapolis Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '4',
#   'agent': 'Juvy Sudario',
#   'office': 'Prime Realty Group',
#   'price': '89750'},
#  {'neighborhood': 'home owned estates',
#   'address': '13355 Joliet Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '17',
#   'agent': 'Hernan Garcia',
#   'office': 'Turn Key Realty',
#   'price': '149900'},
#  {'neighborhood': 'home owned estates',
#   'address': '13318 Peoria Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '62',
#   'agent': 'Omar Scanu',
#   'office': 'RE/MAX 1st Source',
#   'price': '45500'},
#  {'neighborhood': 'home owned estates',
#   'address': '0 Mobile Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '184',
#   'agent': 'Jeff Denning',
#   'office': 'Turner Mangum,LLC',
#   'price': '160000'},
#  {'neighborhood': 'home owned estates',
#   'address': '1050 Glenalbyn Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '248',
#   'agent': 'Omar Scanu',
#   'office': 'RE/MAX 1st Source',
#   'price': '24500'},
#  {'neighborhood': 'home owned estates',
#   'address': '1126 Westmont Drive',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77015',
#   'days': '367',
#   'agent': 'Lou Rosas',
#   'office': 'RE/MAX Real Estate Assoc.',
#   'price': '265000'},
#  {'neighborhood': 'galenapark',
#   'address': '2507 15th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '1',
#   'agent': 'Erik Czirr',
#   'office': 'NextHome First Source',
#   'price': '144500'},
#  {'neighborhood': 'galenapark',
#   'address': '1107 Clinton Drive',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '17',
#   'agent': 'Ellen Holt',
#   'office': 'RE/MAX Associates Northeast',
#   'price': '275000'},
#  {'neighborhood': 'galenapark',
#   'address': '2516 6th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '17',
#   'agent': 'Denes Jafari',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene - Champions',
#   'price': '145000'},
#  {'neighborhood': 'galenapark',
#   'address': '2503 9th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '26',
#   'agent': 'Emelita Rhoades',
#   'office': 'Realty World Elite Group',
#   'price': '189999'},
#  {'neighborhood': 'galenapark',
#   'address': '2515 5th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '31',
#   'agent': 'Roosevelt Mucker',
#   'office': 'Generation Realty, LLC',
#   'price': '99500'},
#  {'neighborhood': 'galenapark',
#   'address': '2516 15th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '15',
#   'agent': 'Gloria Gutierrez',
#   'office': 'The Horizon Team',
#   'price': '169999'},
#  {'neighborhood': 'galenapark',
#   'address': '1501 Bank Drive',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '37',
#   'agent': 'Gloria Gutierrez',
#   'office': 'The Horizon Team',
#   'price': '129999'},
#  {'neighborhood': 'galenapark',
#   'address': '1905 11th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '110',
#   'agent': 'Thelma Ibarra',
#   'office': 'Houston Realty',
#   'price': '120900'},
#  {'neighborhood': 'galenapark',
#   'address': '2513 11th Street',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '87',
#   'agent': 'Ana Gonzalez',
#   'office': 'Circa Real Estate LLC',
#   'price': '142500'},
#  {'neighborhood': 'galenapark',
#   'address': '1712 10th',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '110',
#   'agent': 'Belinda Malone',
#   'office': 'Keller Williams Memorial',
#   'price': '108000'},
#  {'neighborhood': 'galenapark',
#   'address': '1607 Clinton Drive',
#   'city': 'Galena Park',
#   'state': 'TX',
#   'zip': '77547',
#   'days': '147',
#   'agent': 'Jose Ramon',
#   'office': 'Can-2 Realty',
#   'price': '379000'},
#  {'neighborhood': 'braeburn glen',
#   'address': '8811 Imogene Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77074',
#   'days': '5',
#   'agent': 'Nguyen Wilson',
#   'office': 'Wilson Realty & Inv Grp, LLC',
#   'price': '135000'},
#  {'neighborhood': 'braeburn glen',
#   'address': '8711 Reamer Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77074',
#   'days': '18',
#   'agent': 'Wayne Comer',
#   'office': '360 Realty & Management',
#   'price': '215000'},
#  {'neighborhood': 'braeburn glen',
#   'address': '8706 Jason Street',
#   'city': 'Houston',
#   'state': 'TX',
#   'zip': '77074',
#   'days': '169',
#   'agent': 'Nguyen Wilson',
#   'office': 'Wilson Realty & Inv Grp, LLC',
#   'price': '219000'},
#  {'neighborhood': 'highland shores',
#   'address': 'LT 27 Highland Shores Road',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '112',
#   'agent': 'Veronica Gamez',
#   'office': 'Coldwell Banker United, REALTORS- Baytown',
#   'price': '19900'},
#  {'neighborhood': 'highland shores',
#   'address': '00 Shorewick Drive',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '272',
#   'agent': 'Emiliano Nino',
#   'office': 'Mission Realty',
#   'price': '75000'},
#  {'neighborhood': 'highland shores',
#   'address': '0 Shorewick Drive',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '272',
#   'agent': 'Emiliano Nino',
#   'office': 'Mission Realty',
#   'price': '75000'},
#  {'neighborhood': 'highland shores',
#   'address': '2425 Shorewick Drive',
#   'city': 'Highlands',
#   'state': 'TX',
#   'zip': '77562',
#   'days': '173',
#   'agent': 'Emiliano Nino',
#   'office': 'Mission Realty',
#   'price': '250000'},
#  {'neighborhood': 'san jacinto river estates',
#   'address': '17404 Moreland Drive',
#   'city': 'Channelview',
#   'state': 'TX',
#   'zip': '77530',
#   'days': '29',
#   'agent': 'Dessiree Macias',
#   'office': 'Keller Williams Realty Metropolitan',
#   'price': '250000'},
#  {'neighborhood': 'bliss meadows',
#   'address': '5816 Melinda Lane',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '9',
#   'agent': 'Renee Taylor',
#   'office': 'Prince Properties, LLC',
#   'price': '199900'},
#  {'neighborhood': 'bliss meadows',
#   'address': '5802 Lucy Lane',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '21',
#   'agent': 'Lance Loken',
#   'office': 'Keller Williams Platinum',
#   'price': '150000'},
#  {'neighborhood': 'bliss meadows',
#   'address': '5816 S Meadow Drive',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '46',
#   'agent': 'Ozzie Ramirez',
#   'office': 'Keller Williams Realty',
#   'price': '190000'},
#  {'neighborhood': 'crest haven estates',
#   'address': '6419 Olson Lane',
#   'city': 'Pasadena',
#   'state': 'TX',
#   'zip': '77505',
#   'days': '3',
#   'agent': 'James Toler',
#   'office': 'Logos Investment Properties',
#   'price': '155000'},
#  {'neighborhood': 'spenwick place',
#   'address': '9414 Spencer Hwy Highway',
#   'city': 'La Porte',
#   'state': 'TX',
#   'zip': '77571',
#   'days': '96',
#   'agent': 'Mary Carrizal',
#   'office': 'Main Properties',
#   'price': '199900'},
#  {'neighborhood': 'spenwick place',
#   'address': '9406 Spencer Hwy Highway',
#   'city': 'La Porte',
#   'state': 'TX',
#   'zip': '77571',
#   'days': '96',
#   'agent': 'Mary Carrizal',
#   'office': 'Main Properties',
#   'price': '796599'}]
