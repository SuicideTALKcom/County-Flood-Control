# %%
import csv
import requests
from bs4 import BeautifulSoup
from pprint import pprint

from urllib import parse
import json
import pandas as pd
import time

def har_homes():

    urls = ["https://www.har.com/mapsearch/?subdivisions=NorthWest+Park+place&region_id=1&for_sale=1",
            "https://www.har.com/mapsearch/?subdivisions=lismore+lake+estates&for_sale=1",
           "https://www.har.com/mapsearch/?subdivisions=lakewood+oaks+estates&region_id=1&for_sale=1",
           "https://www.har.com/mapsearch/?subdivisions=Riata+West&region_id=1&for_sale=1",
           "https://www.har.com/mapsearch/?subdivisions=Saddle+Ridge+Estates&region_id=1&for_sale=1"]

    all_homes = []

    for index,url in enumerate(urls):
        html = requests.get(url).text
        soup = BeautifulSoup(html, "html.parser")
        homes = soup.findAll('div', {"class": "map_prop_item pointer"})
        neighborhood = dict(parse.parse_qsl(parse.urlsplit(url).query))
        home_info = dict()
        home_info['home_url'] = homes
        home_info['neighborhood'] = neighborhood    
        all_homes.append(home_info)

    resultset = []

    # for homes in all_homes:
    for homes in all_homes:
        for home in homes['home_url']:
            home_details = dict()
            home_details['address'] = home.find('div', {'class': 'mpi_info'}).text.strip('\n\r\t": ').strip('\n\r\t": ').strip('\n\r\t": ').split('\n')[0]
            home_details['price'] = home.find('div', {'class': 'price'}).text.strip('\n\r\t": ').strip('\n\r\t": ').strip('\n\r\t": ').replace(',','').replace('$','')
            home_details['days'] = home.find('span', {'class': 'bold'}).text.strip('\n\r\t": ').strip('\n\r\t": ').strip('\n\r\t": ')
            home_details['agent'] = home.find('div', {'class': 'capitalize bold'}).text.strip('\n\r\t": ').strip('\n\r\t": ').strip('\n\r\t": ')
            home_details['office'] = home.find('div', {'class': 'capitalize ellipse'}).text.strip('\n\r\t": ').strip('\n\r\t": ').strip('\n\r\t": ')
            home_details['neighborhood'] = homes['neighborhood']['subdivisions']
            resultset.append(home_details)   
    return resultset

har_homes()
# Out:
# [{'address': '9827 Golden Prairie Lane',
#   'price': ' 195000',
#   'days': '11',
#   'agent': 'Isaias Contreras',
#   'office': 'Keller Williams Signature',
#   'neighborhood': 'NorthWest Park place'},
#  {'address': '6035 Cascadera Drive',
#   'price': ' 195000',
#   'days': '35',
#   'agent': 'Phuong Nguyen',
#   'office': 'BlueRoof Real Estate, LLC',
#   'neighborhood': 'NorthWest Park place'},
#  {'address': '10110 Fallmont Court',
#   'price': ' 170000',
#   'days': '8',
#   'agent': 'Alexander Ebner',
#   'office': 'Coldwell Banker United, Realtors - Bellaire Office',
#   'neighborhood': 'NorthWest Park place'},
#  {'address': '5822 Wickover Lane',
#   'price': ' 169990',
#   'days': '5',
#   'agent': 'Ruben Villarreal',
#   'office': 'RE/MAX Integrity',
#   'neighborhood': 'NorthWest Park place'},
#  {'address': '12035 Lismore Lake Drive',
#   'price': ' 349900',
#   'days': '56',
#   'agent': 'Mitchell Haynes',
#   'office': 'BuyBroker',
#   'neighborhood': 'lismore lake estates'},
#  {'address': '12151 Lismore Lake Drive',
#   'price': ' 329900',
#   'days': '45',
#   'agent': 'Jennifer Ciulla',
#   'office': 'RE/MAX Fine Properties',
#   'neighborhood': 'lismore lake estates'},
#  {'address': '11918 Galentine Point',
#   'price': ' 289900',
#   'days': '176',
#   'agent': 'Amjad Mushtaq',
#   'office': 'Fast Homes',
#   'neighborhood': 'lismore lake estates'},
#  {'address': '13910 Springmint Drive',
#   'price': ' 615000',
#   'days': '5',
#   'agent': 'John Prell',
#   'office': 'Creekview Realty',
#   'neighborhood': 'lakewood oaks estates'},
#  {'address': '13718 Pegasus Road',
#   'price': ' 529000',
#   'days': '24',
#   'agent': 'Young Le',
#   'office': 'Texas Independence Realty',
#   'neighborhood': 'lakewood oaks estates'},
#  {'address': '13511 Pegasus Road',
#   'price': ' 499500',
#   'days': '30',
#   'agent': 'Teresa Goralski',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene',
#   'neighborhood': 'lakewood oaks estates'},
#  {'address': '13106 Springmint Court',
#   'price': ' 499500',
#   'days': '116',
#   'agent': 'Evan Compean',
#   'office': 'Champions Real Estate Group',
#   'neighborhood': 'lakewood oaks estates'},
#  {'address': '14011 Pegasus Circle',
#   'price': ' 465000',
#   'days': '214',
#   'agent': 'Mark Raisbeck',
#   'office': 'RE/MAX Elite Properties',
#   'neighborhood': 'lakewood oaks estates'},
#  {'address': '13618 Pegasus Road',
#   'price': ' 450000',
#   'days': '10',
#   'agent': 'Stephanie Martens',
#   'office': 'Better Homes and Gardens Real Estate Gary Greene',
#   'neighborhood': 'lakewood oaks estates'}]
