# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd
import matplotlib 
import numpy as np 

engine = create_engine("mysql+pymysql://root:banana@localhost/homes_db", echo=False)

# %%
csv_path = "../Margret/homes3.csv"
homes_df = pd.read_csv(csv_path)
homes_df.head()
homes_df
# Out:
#                        Address        Price  Days on Market  \
# 0     9827 Golden Prairie Lane    $ 195,000               6
# 1         6035 Cascadera Drive    $ 195,000              35
# 2         10110 Fallmont Court    $ 170,000               8
# 3           5822 Wickover Lane    $ 169,990               5
# 4     12035 Lismore Lake Drive    $ 349,900              54
# 5     12151 Lismore Lake Drive    $ 329,900              43
# 6        11918 Galentine Point    $ 289,900             174
# 7       13910 Springmint Drive    $ 615,000               5
# 8           13718 Pegasus Road    $ 529,000              22
# 9           13511 Pegasus Road    $ 499,500              28
# 10      13106 Springmint Court    $ 499,500             114
# 11        14011 Pegasus Circle    $ 465,000             212
# 12          13618 Pegasus Road    $ 450,000               8
# 13     11207 Barker West Drive    $ 298,799             128
# 14     10923 Barker View Drive    $ 225,000              17
# 15     10902 Barker View Drive    $ 224,900               2
# 16    17923 Cypress Side Drive    $ 224,500              27
# 17    17951 Branch Creek Drive    $ 198,500              11
# 18  18030 Riata Crossing Drive    $ 189,900              80
# 19     10915 Barker View Drive    $ 179,999               4
# 20    11115 Riata Canyon Drive    $ 179,900               1
# 21     16810 Saddle Ridge Pass  $ 4,999,500              15
# 22     17203 Saddle Ridge Pass  $ 2,150,000             163
# 23     16510 Saddle Ridge Pass  $ 1,997,000             134
# 24     16703 Saddle Ridge Pass  $ 1,258,000              27
#
#                 Agent                                             Office  \
# 0    Isaias Contreras                          Keller Williams Signature
# 1       Phuong Nguyen                               BlueRoof Real Estate
# 2     Alexander Ebner  Coldwell Banker United, Realtors - Bellaire Of...
# 3    Ruben Villarreal                                   RE/MAX Integrity
# 4     Mitchell Haynes                                          BuyBroker
# 5     Jennifer Ciulla                             RE/MAX Fine Properties
# 6       Amjad Mushtaq                                         Fast Homes
# 7          John Prell                                   Creekview Realty
# 8            Young Le                          Texas Independence Realty
# 9     Teresa Goralski   Better Homes and Gardens Real Estate Gary Greene
# 10       Evan Compean                        Champions Real Estate Group
# 11      Mark Raisbeck                            RE/MAX Elite Properties
# 12  Stephanie Martens                                  BHGRE Gary Greene
# 13   Darrell Anderson                                    Nino Properties
# 14     Jimmy Franklin                                     eXp Realty LLC
# 15     Claudia Ocadiz                              Blake Richards Realty
# 16     Cameron Namazi                                      Summit Realty
# 17     Candice Harris                                   CA Modern Realty
# 18      Cesar Ramirez                                         Vylla Home
# 19      Alian Johnson                        Champions Real Estate Group
# 20    Allison Fontana                                Texas Realty Select
# 21   William Phillips                           John Daugherty, Realtors
# 22       Clint Nabors   Better Homes and Gardens Real Estate Gary Greene
# 23      Sharon Vaughn                                    Zuri Properties
# 24       Mark Bonning                                Bonning Real Estate
#
#              Neighborhood
# 0    NorthWest Park place
# 1    NorthWest Park place
# 2    NorthWest Park place
# 3    NorthWest Park place
# 4    lismore lake estates
# 5    lismore lake estates
# 6    lismore lake estates
# 7   lakewood oaks estates
# 8   lakewood oaks estates
# 9   lakewood oaks estates
# 10  lakewood oaks estates
# 11  lakewood oaks estates
# 12  lakewood oaks estates
# 13             Riata West
# 14             Riata West
# 15             Riata West
# 16             Riata West
# 17             Riata West
# 18             Riata West
# 19             Riata West
# 20             Riata West
# 21   Saddle Ridge Estates
# 22   Saddle Ridge Estates
# 23   Saddle Ridge Estates
# 24   Saddle Ridge Estates

# %%
# hood_df = homes_df.groupby("Neighborhood")
# hood_df.head()

# hood_df2 = pd.DataFrame(hood_df)
# hood_df2

# %%
# hood_df2.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
homes_df.to_sql('home', if_exists = 'append', con=engine)
